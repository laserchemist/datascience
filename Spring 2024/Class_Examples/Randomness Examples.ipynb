# %% [markdown]
# ### Randomness
# Elements of Data Science Week 5

# %% [markdown]
# ## Lab 05 Learning Goals
# - Booleans and conditionals
#     - Conditional statements: if, elif, else
#     - `>, <, ==, <=, >=, !=`
# - Iteration: `for i in np.arange(10)`
# - Probability
#     - Analytical
#         - 6-sided die: P(3) = 1/6
#     - Numerical: simulation

# %% [markdown]
# #### A random distributions play a large role in statistical inference

# %%
import numpy as np
from datascience import *

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Die role

# %%
roll = np.arange(1,7)
roll
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.random.choice(roll,2)
# Out:
# array([6, 6])

# %%
rolls = np.random.choice(roll,6)
rolls
# Out:
# array([2, 1, 6, 4, 3, 2])

# %%
die_rolls = Table().with_columns("roll",np.random.choice(roll,80))
die_rolls.hist(bins=np.arange(1,8))

# %%
die_rolls
# Out:
# roll
# 5
# 6
# 2
# 6
# 2
# 2
# 4
# 6
# 2
# 5
# ... (70 rows omitted)

# %%
die_rolls.hist(bins=np.arange(1,8))

# %%
die_rolls.where('roll',6).num_rows/die_rolls.num_rows
# Out:
# 0.1875

# %%
5/6
# Out:
# 0.8333333333333334

# %%
die_rolls.hist(bins=np.arange(1,8))

# %%
rolls = []
for i in np.arange(10):
    rolls.append(np.random.choice(roll))
rolls
# Out:
# [3, 5, 5, 3, 1, 3, 4, 5, 5, 4]

# %% [markdown]
# #### Randomized control study

# %%
two_groups = np.array(['treatment', 'control'])
np.random.choice(two_groups)
# Out:
# 'treatment'

# %%
np.random.choice(two_groups, 10)
# Out:
# array(['treatment', 'treatment', 'treatment', 'treatment', 'control',
#        'treatment', 'control', 'control', 'treatment', 'control'],
#       dtype='<U9')

# %% [markdown]
# #### Coin toss

# %%
toss = np.array(['Heads', 'Tails'])
tosses=np.random.choice(toss,10)
tosses == 'Heads'
# Out:
# array([ True,  True, False,  True, False, False,  True,  True, False,  True], dtype=bool)

# %%
np.count_nonzero(tosses == 'Heads')
# Out:
# 6

# %% [markdown]
# ---
# ## PA Pick 4
# <img src="Pick4.png" />

# %%
pick = np.random.choice(np.arange(10000),5)
print('\n'.join('{}: {:04}'.format(*k) for k in enumerate(pick))) #Special; print
# Out:
# 0: 3789
# 1: 4218
# 2: 1437
# 3: 0527
# 4: 9140

# %%
draw = np.random.choice(np.arange(10000))
print('{:04}'.format(draw) ) #Special; print
# Out:
# 5709

# %%
if draw in pick:
    print("Win")
else:
    print("Better luck next time")
# Out:
# Better luck next time

# %% [markdown]
# ---
# ## Dice game gambling
#
# * roll: 0 or 1 = -\$1
# * roll: 2 or 3 =  0
# * roll: 4 or 5 = +\$1

# %%
def bet_on_one_roll():
    """Returns my net gain on one bet"""
    x = np.random.choice(np.arange(1, 7))  # roll a die once and record the number of spots
    if x <= 2:
        return -1
    elif x <= 4:
        return 0
    elif x <= 6:
        return 1

# %%
np.sum(np.random.choice(np.arange(1, 7),3))

# %%
pick = 4195

# %% [markdown]
# #### Iteration

# %%
outcomes = np.array([])

for i in np.arange(600):
    outcome_of_bet = bet_on_one_roll()
    outcomes = np.append(outcomes, outcome_of_bet)
    
print(outcomes[0:10])
len(outcomes)

# %%
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
outcome_table = Table().with_column('Outcome', outcomes)
outcome_table.group('Outcome').barh(0)
