# %% [markdown]
# ### Hypothesis testing: Lab 7
#
# Elements of Data Science

# %%
import numpy as np
from datascience import *

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Fix for datascience plots
import collections as collections
import collections.abc as abc
collections.Iterable = abc.Iterable

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# **Question 7: Complete the simulation below, which samples num_changes increases/decreases at random many times and forms an empirical distribution of your test statistic under the null hypothesis.**
#
# Your job is to:
# fill in the function simulate_under_null, which simulates a single sample under the null hypothesis, and
# fill in its argument when it's called below.
# **As a hint, num_changes should be approximately the number of countries times the number of time comparisons (you can find the number of year comparisons by using diff_n().**

# %% [raw]
# def simulate_under_null(num_chances_to_change):
#     """Simulates some number changing several times, with an equal
#     chance to increase or decrease.  Returns the value of your
#     test statistic for these simulated changes.
#
#     num_chances_to_change is the number of times the number changes.
#     """
#     uniform = Table().with_columns(
#         "Change", make_array('Increase', 'Decrease'),
#         "Chance", make_array(0.5,        0.5))
#     sample = ...
#
#     ...
#
#     return ...

# %% [raw]
# def empirical_distribution(tbl):
#     num_changes = ...
#     samples = make_array()
#     for i in np.arange(10000):
#         samples = np.append(samples, simulate_under_null(...))
#     Table().with_column('Test statistic under null', samples).hist(bins=np.arange(0, max(samples) + max(samples) * 0.1, 2))
#     return samples

# %% [raw]
# samples = empirical_distribution(...)

# %% [markdown]
# ## How to approach the problem

# %% [markdown]
# ### Step 1: Make sure you understand the part of the function that was given to you.

# %%
uniform = Table().with_columns(
    "Change", make_array('Increase', 'Decrease'),
    "Chance", make_array(0.5,        0.5))

uniform
# Out:
# Change   | Chance
# Increase | 0.5
# Decrease | 0.5

# %% [markdown]
# ### Step 2: Try the sample the sample_from_distribution method of datatables.

# %%
sample = uniform.sample_from_distribution('Chance', 10)
sample
# Out:
# Change   | Chance | Chance sample
# Increase | 0.5    | 4
# Decrease | 0.5    | 6

# %% [markdown]
# ### Step 3: Add this to your function
# For the each sample created by the simulation we have to simulate having the same amount of data as in our observation.

# %%
def simulate_under_null(num_chances_to_change):
    """Simulates some number changing several times, with an equal
    chance to increase or decrease.  Returns the value of your
    test statistic for these simulated changes.
    
    num_chances_to_change is the number of times the number changes.
    """
    uniform = Table().with_columns(
        "Change", make_array('Increase', 'Decrease'),
        "Chance", make_array(0.5,        0.5))
    sample = uniform.sample_from_distribution('Chance', num_chances_to_change)
    return sample

# %%
sample = simulate_under_null(10)
sample
# Out:
# Change   | Chance | Chance sample
# Increase | 0.5    | 2
# Decrease | 0.5    | 8

# %% [markdown]
# ## Step 4: We want to return the net positive increases

# %%
net = sample.column('Chance sample')[0] - sample.column('Chance sample')[1]
net
# Out:
# -6

# %% [markdown]
# ## Step 5: Add this to you function, too.

# %%
def simulate_under_null(num_chances_to_change):
    """Simulates some number changing several times, with an equal
    chance to increase or decrease.  Returns the value of your
    test statistic for these simulated changes.
    
    num_chances_to_change is the number of times the number changes.
    """
    uniform = Table().with_columns(
        "Change", make_array('Increase', 'Decrease'),
        "Chance", make_array(0.5,        0.5))
    sample = uniform.sample_from_distribution('Chance', num_chances_to_change)
    net = sample.column('Chance sample')[0] - sample.column('Chance sample')[1]
    return net

# %%
sample = simulate_under_null(10)
sample
# Out:
# -4

# %% [markdown]
# ## Step 6: Look at the second function

# %% [raw]
# def empirical_distribution(tbl):
#     num_changes = ...
#     samples = make_array()
#     for i in np.arange(10000):
#         samples = np.append(samples, simulate_under_null(...))
#     Table().with_column('Test statistic under null', samples).hist(bins=np.arange(0, max(samples) + max(samples) * 0.1, 2))
#     return samples

# %% [markdown]
# The function is nearly complete. It just wants your to figure out the correct value for num_changes. **Look back at the hint!**
# "As a hint, num_changes should be approximately the number of countries times the number of time comparisons (you can find the number of year comparisons by using diff_n()."

# %%
def diff_n(values, n):
    return np.array(values)[n:] - np.array(values)[:-n]

diff_n(make_array(1, 10, 100, 1000, 10000), 2)
# Out:
# array([  99,  990, 9900])

# %% [markdown]
# Notice that the number of changes is just one less than the number of values in the array. In this case, that would be then number of years of temperature data available for each country.
# How do we find that?

# %%
# Example Table
example = Table().with_columns(
    "Year",
    make_array(2000, 2001, 2002, 2003, 2000, 2001, 2002),
    "Country",
    make_array("France", "France", "France", "France", "England", "England", "England"),
)
example
# Out:
# Year | Country
# 2000 | France
# 2001 | France
# 2002 | France
# 2003 | France
# 2000 | England
# 2001 | England
# 2002 | England

# %%
grouped_example = example.group("Country")
grouped_example
# Out:
# Country | count
# England | 3
# France  | 4

# %%
np.sum(grouped_example.column('count'))
# Out:
# 7

# %%
len(np.unique(example.column('Country')))
# Out:
# 2

# %%
num_changes = np.sum(grouped_example.column('count')) - len(np.unique(example.column('Country')))
num_changes
# Out:
# 5

# %%
def empirical_distribution(tbl):
    num_changes = ...
    samples = make_array()
    for i in np.arange(10000):
        samples = np.append(samples, simulate_under_null(...)) 
    Table().with_column('Test statistic under null', samples).hist(bins=np.arange(0, max(samples) + max(samples) * 0.1, 2))
    return samples

# %% [markdown]
# This function is ready for you to pass in the table: changes_by_country after you fix num_changes.

# %% [markdown]
# ## HINTS: Mount St. Helens Mini-project

# %%
# Plot description dataset
datafile = "../../Mini Project II/data/MSH_PLOT_DESCRIPTORS2.csv"
MSH_PLOT = Table.read_table(datafile)
MSH_PLOT.where('PLOT_CODE','ABPL10')
# Out:
# PLOT_NAME       | PLOT_CODE | FIRST_YEAR | LAST_YEAR | UTMGRID | UTMEAST | UTMNORTH | LONG    | LAT     | POT._RAD. | HEAT_LOAD | ELEVATION(M) | ASPECT | SLOPE | IMPACT_TYPE          | SUCCESSION_TYPE
# Abraham Plain10 | ABPL10    | 1995       | 2009      | 10T     | 566130  | 5117818  | 122.143 | 46.2107 | 0.893     | 0.881     | 1376         | E      | 2     | Blast; Scour; Pumice | Primary

# %%
np.unique(MSH_PLOT['PLOT_CODE'])
# Out:
# array(['ABPL01', 'ABPL02', 'ABPL03', 'ABPL04', 'ABPL05', 'ABPL06',
#        'ABPL07', 'ABPL08', 'ABPL09', 'ABPL10', 'BUCA01', 'BUCA03',
#        'BUCA04', 'BUCB01', 'BUCB02', 'BUCB03', 'BUCB04', 'BUCB05',
#        'BUCB06', 'BUCB07', 'BUCC01', 'BUCC02', 'BUCC03', 'BUCD01',
#        'BUCD02', 'BUCD03', 'BUCD05', 'LAH04', 'LAH05', 'LAH06', 'LAH07',
#        'LAH08', 'LAHR01', 'LAHR02', 'PICA01', 'PICA02', 'PICA03', 'PICA04',
#        'PICB01', 'PICB02', 'PICB03', 'PICB04', 'PICB05', 'PICE02',
#        'PICE03', 'PICE04', 'PUPL01', 'PUPL02', 'PUPL03', 'PUPL04',
#        'PUPL05', 'PUPL06', 'PUPL07', 'PUPL08', 'PUPL09', 'PUPL10',
#        'PUPL11', 'PUPL12', 'SFTR01', 'SFTR02', 'SFTR03', 'SFTR04',
#        'STRD01', 'STRD02', 'STRD03', 'STRD04', 'STRD05', 'STRD06',
#        'STRD07', 'STRD08', 'STRD09', 'STRD10', 'STRD11', 'STRD12',
#        'STRD13', 'STRD14', 'STRD15', 'STRD16', 'STRD17', 'STRD18',
#        'STRD19', 'STRD20', 'TORD01', 'TORD02', 'TORD03', 'TORD04',
#        'TORD05', 'TORD06', 'TORD07', 'TORD08', 'TORD09', 'TORD10'],
#       dtype='<U6')

# %%
MSH_PLOT = MSH_PLOT.with_columns('NLONG',-1*(MSH_PLOT.column('LONG')))
MSH_map = MSH_PLOT.select('LAT', 'NLONG', 'PLOT_CODE').relabel('PLOT_CODE', 'labels')
Circle.map_table(MSH_map, color='blue',area=200)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a14b046a022947503446582331d3caa {
#                     position: relative;
#                     width: 960.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a14b046a022947503446582331d3caa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a14b046a022947503446582331d3caa = L.map(
#                 &quot;map_1a14b046a022947503446582331d3caa&quot;,
#                 {
#                     center: [46.19464, -122.18735000000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     clusteredMarker: false,
#                     includeColorScaleOutliers: true,
#                     radiusInMeters: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a0355fd17760b79c80bd9e9177fb49f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 17, &quot;maxZoom&quot;: 17, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a14b046a022947503446582331d3caa);
#
#
#             var circle_marker_9f40554415ca0ebc56e62e9028ebe9d6 = L.circleMarker(
#                 [46.21457, -122.22569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.978845608028654, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a14b046a022947503446582331d3caa);
#
#
#         var popup_c00845e0f5ea23b2b4284831b7674a76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_116a09964714346e69fe66e634c28085 = $(`&lt;div id=&quot;html_116a09964714346e69fe66e634c28085&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TORD10&lt;/div&gt;`)[0];
#                 popup_c00845e0f5ea23b2b4284831b7674a76.setContent(html_116a09964714346e69fe66e634c28085);
#
#
#
#         circle_marker_9f40554415ca0ebc56e62e9028ebe9d6.bindPopup(popup_c00845e0f5ea23b2b4284831b7674a76)
#         ;
#
#
#
#
#             var circle_marker_7be980d455e73d44d2d1baa6f7245ab6 = L.circleMarker(
#                 [46.21491, -122.22731],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.978845608028654, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a14b046a022947503446582331d3caa);
#
#
#         var popup_a7c184e09b3cf656f78daf886fe0bacb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_076758e04abb87c82c63c8eb01023a4b = $(`&lt;div id=&quot;html_076758e04abb87c82c63c8eb01023a4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TORD09&lt;/div&gt;`)[0];
#                 popup_a7c184e09b3cf656f78daf886fe0bacb.setContent(html_076758e04abb87c82c63c8eb01023a4b);
#
#
#
#         circle_marker_7be980d455e73d44d2d1baa6f7245ab6.bindPopup(popup_a7c184e09b3cf656f78daf886fe0bacb)
#         ;
#
#
#
#
#             var circle_marker_e34a4c2e7e02b11ca807d936060f1336 = L.circleMarker(
#                 [46.2155, -122.22774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.978845608028654, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a14b046a022947503446582331d3caa);
#
#
#         var popup_5912a5c5af4a8c175af21c5af1f1fe29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18de154f13eb4f04ed5fd5938db1e23c = $(`&lt;div id=&quot;html_18de154f13eb4f04ed5fd5938db1e23c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TORD08&lt;/div&gt;`)[0];
#                 popup_5912a5c5af4a8c175af21c5af1f1fe29.setContent(html_18de154f13eb4f04ed5fd5938db1e23c);
#
#
#
#         circle_marker_e34a4c2e7e02b11ca807d936060f1336.bindPopup(popup_5912a5c5af4a8c175af21c5af1f1fe29)
#         ;
#
#
#
#
#             var circle_marker_3c47d6dbc57a4723738835a4ab65f534 = L.circleMarker(
#                 [46.21569, -122.22902],

# %%
datafile = "../../Mini Project II/data/MSH_STRUCTURE_PLOT_YEAR.csv"
MSH_YEAR = Table.read_table(datafile)
MSH_YEAR.show(4)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLOT_ID</th> <th>PLOT_NAME</th> <th>PLOT_NUMBER</th> <th>YEAR</th> <th>RICHNESS</th> <th>COVER_%</th> <th>HPRIME</th> <th>EVENNESS</th> <th>FREQUENCY</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ABPL011995</td> <td>ABPL     </td> <td>1          </td> <td>1995</td> <td>14      </td> <td>2.2    </td> <td>2.41  </td> <td>0.913   </td> <td>7.7      </td>
#         </tr>
#         <tr>
#             <td>ABPL011996</td> <td>ABPL     </td> <td>1          </td> <td>1996</td> <td>17      </td> <td>2.9    </td> <td>2.524 </td> <td>0.891   </td> <td>8.1      </td>
#         </tr>
#         <tr>
#             <td>ABPL011997</td> <td>ABPL     </td> <td>1          </td> <td>1997</td> <td>18      </td> <td>4.2    </td> <td>2.231 </td> <td>0.772   </td> <td>11.6     </td>
#         </tr>
#         <tr>
#             <td>ABPL011999</td> <td>ABPL     </td> <td>1          </td> <td>1999</td> <td>19      </td> <td>5.9    </td> <td>2.268 </td> <td>0.77    </td> <td>14.2     </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1739 rows omitted)</p>

# %%
np.unique(MSH_YEAR['PLOT_NAME'])
# Out:
# array(['ABPL', 'BUCA', 'BUCB', 'BUCC', 'BUCD', 'LAHR', 'PICA', 'PICB',
#        'PICE', 'PUPL', 'SFTR', 'STRD', 'TORD'],
#       dtype='<U4')

# %% [markdown]
# ## Comparing plots

# %%
MSH_YEAR.where('PLOT_NAME','ABPL').scatter("YEAR","COVER_%")

# %%
MSH_YEAR.where('PLOT_NAME','STRD').scatter("YEAR","COVER_%")

# %% [markdown]
# ### Maybe compare average COVER_% for a given year?

# %%
abpl_2000 = MSH_YEAR.where("YEAR", are.equal_to(2000)).where("PLOT_NAME", are.equal_to("ABPL"))
abpl_2000.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLOT_ID</th> <th>PLOT_NAME</th> <th>PLOT_NUMBER</th> <th>YEAR</th> <th>RICHNESS</th> <th>COVER_%</th> <th>HPRIME</th> <th>EVENNESS</th> <th>FREQUENCY</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ABPL012000</td> <td>ABPL     </td> <td>1          </td> <td>2000</td> <td>17      </td> <td>6.2    </td> <td>2.111 </td> <td>0.745   </td> <td>9.1      </td>
#         </tr>
#         <tr>
#             <td>ABPL022000</td> <td>ABPL     </td> <td>2          </td> <td>2000</td> <td>12      </td> <td>5.1    </td> <td>1.594 </td> <td>0.641   </td> <td>12.2     </td>
#         </tr>
#         <tr>
#             <td>ABPL032000</td> <td>ABPL     </td> <td>3          </td> <td>2000</td> <td>21      </td> <td>8.9    </td> <td>2.137 </td> <td>0.702   </td> <td>4.8      </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (7 rows omitted)</p>

# %%
strd_2000 = MSH_YEAR.where("YEAR", are.equal_to(2000)).where("PLOT_NAME", are.equal_to("STRD"))
strd_2000.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLOT_ID</th> <th>PLOT_NAME</th> <th>PLOT_NUMBER</th> <th>YEAR</th> <th>RICHNESS</th> <th>COVER_%</th> <th>HPRIME</th> <th>EVENNESS</th> <th>FREQUENCY</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>STRD012000</td> <td>STRD     </td> <td>1          </td> <td>2000</td> <td>20      </td> <td>59.7   </td> <td>1.775 </td> <td>0.593   </td> <td>23.2     </td>
#         </tr>
#         <tr>
#             <td>STRD022000</td> <td>STRD     </td> <td>2          </td> <td>2000</td> <td>14      </td> <td>62.4   </td> <td>1.207 </td> <td>0.457   </td> <td>27       </td>
#         </tr>
#         <tr>
#             <td>STRD032000</td> <td>STRD     </td> <td>3          </td> <td>2000</td> <td>17      </td> <td>57.4   </td> <td>0.625 </td> <td>0.221   </td> <td>15.8     </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (14 rows omitted)</p>

# %%
two_plots = abpl_2000.append(strd_2000)
two_plots.hist("RICHNESS", group="PLOT_NAME", bins = 20)

# %%
two_plots.group("PLOT_NAME", np.mean)
# Out:
# PLOT_NAME | PLOT_ID mean | PLOT_NUMBER mean | YEAR mean | RICHNESS mean | COVER_% mean | HPRIME mean | EVENNESS mean | FREQUENCY mean
# ABPL      |              | 5.5              | 2000      | 16.9          | 5.82         | 2.0752      | 0.7351        | 8.64
# STRD      |              | 11.0588          | 2000      | 19.0588       | 21.1588      | 1.93318     | 0.654588      | 10.8118

# %% [markdown]
# ### Is the difference in average richness between the two plot you chose statistically significant?

# %% [markdown]
# # Trends over time

# %%
MSH_YEAR.where('PLOT_NAME','ABPL').group("YEAR",np.mean)
# Out:
# YEAR | PLOT_ID mean | PLOT_NAME mean | PLOT_NUMBER mean | RICHNESS mean | COVER_% mean | HPRIME mean | EVENNESS mean | FREQUENCY mean
# 1995 |              |                | 5.5              | 14.1          | 2.75         | 2.2426      | 0.8533        | 6.7
# 1996 |              |                | 5.5              | 15.4          | 3.05         | 2.3348      | 0.8591        | 8.19
# 1997 |              |                | 5.5              | 17.4          | 4.85         | 2.2334      | 0.7871        | 10.01
# 1999 |              |                | 5.5              | 18.2          | 5.52         | 2.2438      | 0.7754        | 9.93
# 2000 |              |                | 5.5              | 16.9          | 5.82         | 2.0752      | 0.7351        | 8.64
# 2001 |              |                | 5.5              | 17.8          | 10.71        | 1.9739      | 0.6895        | 11.9
# 2002 |              |                | 5.5              | 17.9          | 6.66         | 2.0938      | 0.7287        | 12
# 2003 |              |                | 5.5              | 19            | 6.73         | 2.2543      | 0.772         | 14.43
# 2004 |              |                | 5.5              | 18.5          | 8.09         | 2.1048      | 0.729         | 15.44
# 2005 |              |                | 5.5              | 15            | 6.97         | 2.0314      | 0.7583        | 14.86
# ... (4 rows omitted)

# %%
MSH_YEAR.where('PLOT_NAME','ABPL').group("YEAR",np.mean).scatter("YEAR", "COVER_% mean", color='green')
plt.xlim(1995,2010)
# Out:
# (1995.0, 2010.0)

# %% [markdown]
# ## Is this trend random or non-random?  (Same idea as Lab07)
