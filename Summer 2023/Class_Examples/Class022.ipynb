# %% [markdown]
# # Minimize Errors

# %%
## import statements
# These lines load the tests. 
from gofer.ok import check
import numpy as np
from datascience import *
import pandas as pd
import matplotlib
from matplotlib import patches
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore', FutureWarning)
plt.style.use('ggplot')
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
# Fix for datascience collections Iterable
import collections as collections
import collections.abc as abc
collections.Iterable = abc.Iterable

# %%
faithful = Table.read_table("../Lab08/faithful-new.csv")
faithful.scatter('duration','wait')

# %%
def standard_units(xyz):
    "Convert any array of numbers to standard units."
    return (xyz - np.mean(xyz))/np.std(xyz)  
def correlation(t, label_x, label_y):
    return np.mean(standard_units(t.column(label_x))*standard_units(t.column(label_y)))
# Regression
def slope(t, label_x, label_y):
    r = correlation(t, label_x, label_y)
    return r*np.std(t.column(label_y))/np.std(t.column(label_x))
def intercept(t, label_x, label_y):
    return np.mean(t.column(label_y)) - slope(t, label_x, label_y)*np.mean(t.column(label_x))

# %%
correlation(faithful,"duration","wait")
# Out:
# 0.90081116832181318

# %%
faithful.scatter('duration','wait')
slp = slope(faithful, 'duration','wait')
inter = intercept(faithful,'duration','wait')
print("Slope: %4.2f Intercept:  %4.2f" % (slp, inter))
plt.scatter(0,inter)
xs, ys = zip([0, inter], [7, slp*7+inter])
plt.plot(xs,ys, color='blue')
plt.savefig('faithful_regress.png')
plt.show()
# Out:
# Slope: 10.73 Intercept:  33.47

# %%
def mse_c(any_slope,any_intercept):
    tbl = faithful
    xlabel = 'duration'
    ylabel = 'wait'
    xdata, ydata = tbl.column(xlabel), tbl.column(ylabel)
    fitted = any_slope * xdata + any_intercept
    mse = np.mean((ydata - fitted) ** 2)
    print("Root mean squared error:", mse ** 0.5)
    return mse

# %%
mse_c(5,5)
# Out:
# Root mean squared error: 49.2495660766
# 2425.5197587316175

# %%
mse_c(10.73,33.47)
# Out:
# Root mean squared error: 5.89222749007
# 34.718344794770218

# %%
m_slope, m_intercept = minimize(mse_c)
# Out:
# Root mean squared error: 72.1840478548
# Root mean squared error: 72.1840478548
# Root mean squared error: 68.5682096254
# Root mean squared error: 62.7307717633
# Root mean squared error: 11.9478107824
# Root mean squared error: 100.356271475
# Root mean squared error: 39.8913254231
# Root mean squared error: 26.3828312828
# Root mean squared error: 11.9690000063
# Root mean squared error: 11.9690000063
# Root mean squared error: 11.9478107824
# Root mean squared error: 11.7173199537
# Root mean squared error: 11.5198061527
# Root mean squared error: 11.503683385
# Root mean squared error: 11.5458456541
# Root mean squared error: 11.5098443997
# Root mean squared error: 11.5060370726
# Root mean squared error: 11.503728655
# Root mean squared error: 11.503728655
# Root mean squared error: 78.0006323527
# Root mean squared error: 11.503683385
# Root mean squared error: 12.9734163017
# Root mean squared error: 11.452276831
# Root mean squared error: 11.0870845443
# Root mean squared error: 11.1488354543
# Root mean squared error: 11.1411112395
# Root mean squared error: 11.0871269868
# Root mean squared error: 11.0871269868
# Root mean squared error: 11.0870845443
# Root mean squared error: 10.8669748169
# Root mean squared error: 10.7008588781
# Root mean squared error: 10.6967054263
# Root mean squared error: 10.707575892
# Root mean squared error: 10.698292094
# Root mean squared error: 10.6973115072
# Root mean squared error: 10.6967451765
# Root mean squared error: 10.6967451765
# Root mean squared error: 9.91559300119
# Root mean squared error: 10.6967054263
# Root mean squared error: 9.91559300119
# Root mean squared error: 8.72418434653
# Root mean squared error: 5.89222663589
# Root mean squared error: 11.9618881625
# Root mean squared error: 7.1083806308
# Root mean squared error: 6.38416009468
# Root mean squared error: 5.89290292182
# Root mean squared error: 5.89290292182
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.97648180192
# Root mean squared error: 6.11034931521
# Root mean squared error: 5.92455067687
# Root mean squared error: 5.90459420739
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222664664
# Root mean squared error: 5.89222663746
# Root mean squared error: 5.89222663617
# Root mean squared error: 5.89222663595
# Root mean squared error: 5.89222663591
# Root mean squared error: 5.8922266359
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 10.6967054263
# Root mean squared error: 15.6005998449
# Root mean squared error: 8.07226561844
# Root mean squared error: 6.80783213383
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663643
# Root mean squared error: 5.89222663597
# Root mean squared error: 5.89222663591
# Root mean squared error: 5.8922266359
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589
# Root mean squared error: 5.89222663589

# %%
faithful.scatter('duration','wait')
plt.scatter(0,m_intercept)
xs, ys = zip([0, m_intercept], [7, m_slope*7+m_intercept])
plt.plot(xs,ys, color='green')
plt.savefig('faithful_regress_mse.png')
plt.show()
