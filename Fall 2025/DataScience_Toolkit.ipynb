# %% [markdown]
# ## Elements of Data Science for the Life and Physical Sciences
# <font color='red' size=6>Data Science Toolkit

# %% [markdown]
# <img src="Temple_flag_morn.png" alt="Temple Powered" style="width: 200px;"/>

# %% [markdown]
# ## Resources
# - [Inferential Thinking Online Text](https://inferentialthinking.com/chapters/intro.html)
# - [Datascience Table Reference](http://data8.org/datascience/index.html)
# - [Data Science Primer BETA](https://laserchemist.github.io/dprimer/intro.html)
# - [EDS Course Website and Resources](https://sites.temple.edu/data/)
#
# ## Topical Areas
# ### Time Trends and Hypothesis Testing

# %% [markdown]
# - Time Trend data wrangling [Lab 04 Functions and Visualization](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Lab04/Lab04-Functions.ipynb)
# - Changes with time [Lab 7: Inference and Global Climate Change](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Lab07/lab7_statistical_inference.ipynb)

# %% [markdown]
# ```python
# from EDS import *
# Nobel_October = FilterTdate(Nobel,'10/01/2020','10/31/2021')
# ptrend(Nobel_October,"Week","Nobel Prize: (United States)",fmtdate="%b-%Y")</code>
# ```

# %% [markdown]
# ### Difference of Means and Hypothesis Testing
#
# -	Hypothesis Testing (Sampling, Simulation)
# - Lab 06 [Simulation](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Lab06/lab06_simulation.ipynb)
#
# - Normal Distribution (Mean, Standard Deviation)
# - Lab 08 (Variance of Sample Means and Correlation): [Old Faithful Eruption Data](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Lab08/lab8_Variation%26Correlation.ipynb)
# - Testing difference of means: Global warming, difference between 1850 mean temperatures and 2000. [Lab 07](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Lab07/lab7_statistical_inference.ipynb)
#
#
# ### Correlation and Regression
#
# -	Regression & Regression Inference
#     - Lab 09 (Regression), See question 6: [Estimation of the Age of the Universe](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Lab09/lab09-AgeUniverse.ipynb)
#     - EDS Primer see [Regression and Bootstrap Confidence Intervals](https://laserchemist.github.io/dprimer/Regression_bootstrap_CI.html)
#   - [Bootstrap Confidence Intervals](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Class_Examples/Bootstrap_Confidence_Intervals.ipynb)
#
# ### Nearest Neighbors Machine Learning
#
# - Classifiers and Classification
# - Lab 10 (Machine Learning, Classification, & Chemistry): Machine Learning and Chemistry: Alcohol boiling and Molecular Acidity Prediction [link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Lab10/Machine%20Learning%20and%20Chemistry.ipynb)
# - EDS Primer see [k-Nearest Neighbor Classification](https://laserchemist.github.io/dprimer/k-Nearest_Neighbors_classification.html)
# - EDS Primer see [k-Nearest Neighbor Regression](https://laserchemist.github.io/dprimer/k-Nearest_Neighbors_multiple_regression.html)
# - Nearest neighbors [Chronic Kidney Disease classification example](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Class_Examples/Class024_knn%20kidney%20disease.ipynb)

# %% [markdown]
# ### Data Wrangling
# - Converting text or date/time data columns to new columns with numerical hours, month number, etc. [Data Science Primer](https://laserchemist.github.io/dprimer/string_to_number.html)
# - .group
#     - [Inferential Thinking](https://inferentialthinking.com/chapters/07/1/Visualizing_Categorical_Distributions.html?highlight=group#grouping-categorical-data)
#     - [Group and Pivot Examples](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202025/Class_Examples/Table%20group%20and%20pivot%20examples.ipynb)

# %% [markdown]
# ### Data Visualization
# - [Inferential thinking](https://inferentialthinking.com/chapters/07/Visualization.html)
# - [Mapping data using data science Table data](http://www.data8.org/datascience/maps.html)
