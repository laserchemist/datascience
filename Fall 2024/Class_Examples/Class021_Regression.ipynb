# %% [markdown]
# ### Regression Analysis
# Elements Of Data Science

# %%
# Import Numpy and Datascience modules.
import numpy as np
from datascience import *
import pandas as pd

# Plotting 
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', UserWarning)
import collections as collections
import collections.abc as abc
collections.Iterable = abc.Iterable

# %% [markdown]
# ### Correlation

# %%
faithful = Table.read_table("../Lab08/faithful-new.csv")

# %%
faithful.stats()
# Out:
# statistic | duration | wait
# min       | 1.6      | 43
# max       | 5.1      | 96
# median    | 4        | 76
# sum       | 948.677  | 19284

# %%
faithful.scatter('duration','wait')

# %%
# Now plot
plt.style.use('ggplot')
plt.scatter(faithful.column('duration'),faithful.column('wait'))
#faithful.scatter('duration','wait') #
plt.title("Old Faithful")
plt.xlabel("duration (minutes)")
plt.ylabel("wait (minutes)")
plt.savefig("scatter.png") # Helpful way to save figure
plt.show()

# %% [markdown]
# ***
# Standard Units
# ***
# $\bar{x}$=mean$(x)$<br>
# <br>variance=mean$((x-\bar{x})^2)$<br>
# <br>SD = $\sqrt{<(x-\bar{x})^2>}$<br>
# <br>Z = ${\frac{(x-\bar{x})}{SD}}$

# %%
duration_mean =  np.mean(faithful["duration"])
duration_std = np.std(faithful.column("duration"))
wait_mean =  np.mean(faithful.column("wait"))
wait_std = np.std(faithful.column("wait"))

faithful_standard = Table().with_columns(
    "duration (standard units)", (faithful.column("duration") - duration_mean) / duration_std,
    "wait (standard units)", (faithful.column("wait") - wait_mean) / wait_std)
faithful_standard
# Out:
# duration (standard units) | wait (standard units)
# 0.0984989                 | 0.597123
# -1.48146                  | -1.24518
# -0.135861                 | 0.228663
# -1.0575                   | -0.655644
# 0.917443                  | 1.03928
# -0.530851                 | -1.17149
# 1.06403                   | 1.26035
# 0.0984989                 | 1.03928
# -1.3498                   | -1.46626
# 0.756814                  | 1.03928
# ... (262 rows omitted)

# %%
faithful_standard.scatter("duration (standard units)",'wait (standard units)')

# %%
faithful_standard.hist('wait (standard units)')

# %%
np.round(np.mean(faithful_standard["wait (standard units)"]),5)
# Out:
# 0.0

# %%
np.round(np.std(faithful_standard["duration (standard units)"]),5)
# Out:
# 1.0

# %%
faithful_standard.scatter("duration (standard units)", "wait (standard units)")

# %%
r = ...

# %%
r = np.mean(faithful_standard["duration (standard units)"]*faithful_standard["wait (standard units)"])
r
# Out:
# 0.90081116832181318

# %%
def plot_data_and_line(dataset, x, y, point_0, point_1):
    """Makes a scatter plot of the dataset, along with a line passing through two points. x and y are strings containing column labels"""
    xdata = dataset.column(x)
    ydata = dataset.column(y)
    plt.scatter(xdata, ydata, label="data")
    xs, ys = zip(point_0, point_1)
    plt.plot(xs, ys, label="regression line")
    plt.legend(bbox_to_anchor=(1.5,.8))

# %%
plot_data_and_line(faithful_standard, 
                   "duration (standard units)", 
                   "wait (standard units)", 
                   [-2, -2*r], 
                   [2, 2*r])

# %% [markdown]
# ### Alcohol boiling point data

# %%
data_file = '../Lab08/ROH_data.csv'
ROH_data = Table().read_table(data_file)
ROH_data
# Out:
# bp   | MW    | carbons | degree | aliphatic | avg_aryl_position | cyclic
# 338  | 32.04 | 1       | 1      | 1         | 0                 | 0
# 351  | 46.07 | 2       | 1      | 1         | 0                 | 0
# 371  | 60.1  | 3       | 1      | 1         | 0                 | 0
# 356  | 60.1  | 3       | 2      | 1         | 0                 | 0
# 391  | 74.12 | 4       | 1      | 1         | 0                 | 0
# 372  | 74.12 | 4       | 2      | 1         | 0                 | 0
# 381  | 74.12 | 4       | 1      | 1         | 0                 | 0
# 355  | 74.12 | 4       | 3      | 1         | 0                 | 0
# 411  | 88.15 | 5       | 1      | 1         | 0                 | 0
# 404  | 88.15 | 5       | 1      | 1         | 0                 | 0
# ... (62 rows omitted)

# %%
ROH_data.scatter('MW','bp')

# %%
def standard_units(xyz):
    "Convert any array of numbers to standard units."
    return (xyz - np.mean(xyz))/np.std(xyz)  
def correlation(t, label_x, label_y):
    return np.mean(standard_units(t.column(label_x))*standard_units(t.column(label_y)))
# Regression
def slope(t, label_x, label_y):
    r = correlation(t, label_x, label_y)
    return r*np.std(t.column(label_y))/np.std(t.column(label_x))
def intercept(t, label_x, label_y):
    return np.mean(t.column(label_y)) - slope(t, label_x, label_y)*np.mean(t.column(label_x))

# %%
r = np.mean(standard_units(ROH_data.column('MW'))*standard_units(ROH_data['bp']))
r
# Out:
# 0.86738449650478078

# %%
slope(ROH_data,'MW','bp')
# Out:
# 1.4632881415888588

# %% [markdown]
# #### Slope
# ***
#
# slope of the regression line $= r \cdot
# \frac{SD_y}{SD_x}$<br>
# intercept of the regression line $=
# \bar{y} - slope \cdot \bar{x}$

# %% [markdown]
# ## Variability of the Sample Mean
#
# By the Central Limit Theorem, the probability distribution of the mean of a large random sample is roughly normal. The bell curve is centered at the population mean.
#
# <img src='sampling_mean.png' width="500" height="340">

# %% [markdown]
# ### Variability of meaning with Philadelphia voting data

# %%
pres_ward_PHL_2020 = Table().read_table('data/pres_ward_PHL_2020.csv')

# %%
pres_ward_PHL_2020
# Out:
# WARD | PRESIDENT AND VICE-PRESIDENT OF THE UNITED STATES
# JOSEPH R BIDEN AND KAMALA D HARRIS sum | PRESIDENT AND VICE-PRESIDENT OF THE UNITED STATES
# DONALD J TRUMP AND MICHAEL R PENCE sum | PRESIDENT AND VICE-PRESIDENT OF THE UNITED STATES
# JO JORGENSEN AND JEREMY SPIKE COHEN sum | PRESIDENT AND VICE-PRESIDENT OF THE UNITED STATES
# Write-in sum | Registered Voters* | % turnout
# 1    | 7940                                                                                     | 2169                                                                                     | 86                                                                                        | 35                                                             | 13921              | 73.4861
# 2    | 13588                                                                                    | 2102                                                                                     | 103                                                                                       | 60                                                             | 22164              | 71.5259
# 3    | 9186                                                                                     | 204                                                                                      | 30                                                                                        | 21                                                             | 14281              | 66.1088
# 4    | 8833                                                                                     | 211                                                                                      | 40                                                                                        | 14                                                             | 14411              | 63.1323
# 5    | 21797                                                                                    | 3267                                                                                     | 182                                                                                       | 67                                                             | 42366              | 59.7484
# 6    | 6355                                                                                     | 228                                                                                      | 45                                                                                        | 28                                                             | 10657              | 62.4566
# 7    | 5483                                                                                     | 1043                                                                                     | 28                                                                                        | 14                                                             | 13051              | 50.3256
# 8    | 21784                                                                                    | 3328                                                                                     | 156                                                                                       | 83                                                             | 40167              | 63.114
# 9    | 9553                                                                                     | 908                                                                                      | 59                                                                                        | 39                                                             | 12888              | 81.9289
# 10   | 12828                                                                                    | 256                                                                                      | 46                                                                                        | 24                                                             | 17641              | 74.5649
# ... (56 rows omitted)

# %%
pres_ward_PHL_2020.hist('% turnout')
plt.title('Philadelphia 2020 Presidential turnout by ward')
plt.vlines(np.mean(pres_ward_PHL_2020.column('% turnout')),0,.04, label='mean % turnout '+str(round(np.mean(pres_ward_PHL_2020.column('% turnout')),1))+'%')
plt.legend(loc='best')
plt.savefig('2020_turnout.png', bbox_inches='tight')

# %%
sample_PHL_2020 = pres_ward_PHL_2020.sample()
sample_PHL_2020.hist('% turnout')
plt.title('Philadelphia 2020 Presidential turnout by ward, sample')
plt.vlines(np.mean(sample_PHL_2020.column('% turnout')),0,.04, label='mean % turnout '+str(round(np.mean(sample_PHL_2020.column('% turnout')),1))+'%')
plt.legend(loc='best')
plt.savefig('2020_turnout.png', bbox_inches='tight')

# %% [markdown]
# ### Bootstrap sampling

# %%
means = []
for i in np.arange(1000):
    new_sample = pres_ward_PHL_2020.sample()
    new_sample_mean = np.mean(new_sample.column('% turnout'))
    means.append(new_sample_mean)

# %%
plt.hist(np.array(means),bins=25, label='% turnout mean')
plt.xlabel('% turnout')
plt.xlim(50,75)
plt.title('Bootstrap sampled mean turnout')
plt.legend(loc='best')
plt.savefig('2020_turnout_mean.png', bbox_inches='tight')

# %% [markdown]
# #### Empirical distribution of random sample means

# %%
def simulate_sample_mean(table, label, sample_size, repetitions):
    
    means = []

    for i in np.arange(repetitions):
        new_sample = np.random.choice(table.column(label), sample_size)
        new_sample_mean = np.mean(new_sample)
        means.append(new_sample_mean)

    sample_means = Table().with_column('Sample Means', means)
    
    # Display empirical histogram and print all relevant quantities – don't change this!
    fig, ax = plt.subplots()
    ax.hist(means, bins=20)
    plt.xlabel('Sample Means')
    plt.title('Sample Size ' + str(sample_size))
    
    textstr = '\n'.join((
    r'$\mathrm{Sample  Size}=%.2f$' % (sample_size, ),
    r'$\mathrm{Population  Mean}=%.2f$' % (np.mean(table.column(label)), ),
    r'$\mathrm{Average Of Sample Means}=%.2f$' % (np.mean(means), ), 
    r'$\mathrm{Population SD}=%.2f$' % (np.std(table.column(label)), ),
    r'$\mathrm{SD Of Sample Means}=%.2f$' % (np.std(means), )))

    # these are matplotlib.patch.Patch properties
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

    # place a text box in upper left in axes coords
    ax.text(0.95, 0.75, textstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    
    return means

# %% [markdown]
# ### Bootstrap: [Inferential Thinking](https://inferentialthinking.com/chapters/13/2/Bootstrap.html?highlight=bootstrap#the-bootstrap)

# %% [markdown]
# #### Correlation and regression tools

# %%
def standard_units(xyz):
    "Convert any array of numbers to standard units."
    return (xyz - np.mean(xyz))/np.std(xyz)  
def correlation(t, label_x, label_y):
    return np.mean(standard_units(t.column(label_x))*standard_units(t.column(label_y)))
# Regression
def slope(t, label_x, label_y):
    r = correlation(t, label_x, label_y)
    return r*np.std(t.column(label_y))/np.std(t.column(label_x))
def intercept(t, label_x, label_y):
    return np.mean(t.column(label_y)) - slope(t, label_x, label_y)*np.mean(t.column(label_x))

# %% [markdown]
# ##### Apply tools to hybrid car data

# %%
import pandas as pd
url = "hybrid_reg.csv"
hybrid_df = pd.read_csv(url)
hybrid_T = Table.from_df(hybrid_df) # Reading and converting using pandas dataframe
hybrid = Table.read_table(url)
hybrid
hybrid_T
# Out:
# carid | vehicle         | year | msrp    | accelrate | mpg   | mpgmpge | carclass | carclass_id
# 1     | Prius (1st Gen) | 1997 | 24509.7 | 7.46      | 41.26 | 41.26   | C        | 1
# 2     | Tino            | 2000 | 35355   | 8.2       | 54.1  | 54.1    | C        | 1
# 3     | Prius (2nd Gen) | 2000 | 26832.2 | 7.97      | 45.23 | 45.23   | C        | 1
# 4     | Insight         | 2000 | 18936.4 | 9.52      | 53    | 53      | TS       | 7
# 5     | Civic (1st Gen) | 2001 | 25833.4 | 7.04      | 47.04 | 47.04   | C        | 1
# 6     | Insight         | 2001 | 19036.7 | 9.52      | 53    | 53      | TS       | 7
# 7     | Insight         | 2002 | 19137   | 9.71      | 53    | 53      | TS       | 7
# 8     | Alphard         | 2003 | 38084.8 | 8.33      | 40.46 | 40.46   | MV       | 4
# 9     | Insight         | 2003 | 19137   | 9.52      | 53    | 53      | TS       | 7
# 10    | Civic           | 2003 | 14071.9 | 8.62      | 41    | 41      | C        | 1
# ... (143 rows omitted)

# %%
hybrid.scatter('accelrate', 'msrp')

# %%
hybrid.scatter('mpg', 'msrp')

# %%
plt.scatter(standard_units(hybrid.column('accelrate')), standard_units(hybrid.column('msrp')), label="data")

# %%
def plot_data_and_regress(dataset, x, y):
    """Makes a scatter plot of the dataset, and a regression line."""
    xdata, ydata = dataset.column(x), dataset.column(y)
    plt.scatter(standard_units(xdata), standard_units(ydata), label="data in standard units")
    r = correlation(dataset,x,y)
    print("Correlation, r: ",np.round(r,6))
    slp = np.round(slope(dataset,x,y))
    print('Slope of Regression Line:    ', slp, 'y per x')
    intercp = np.round(intercept(dataset,x,y))
    print('Intercept of Regression Line:', intercp, 'y')
    xs, ys = zip([-2, -2*r], [2, 2*r])
    plt.plot(xs, ys, 'r',label="regression line")
    plt.legend(bbox_to_anchor=(1.0,.8))
    dataset.scatter(x,y, label="data in original units")
    xs, ys = zip([xdata.min(), xdata.min()*slp+intercp], [xdata.max(), xdata.max()*slp+intercp])
    plt.plot(xs, ys, 'g',label="regression line")
    plt.legend(bbox_to_anchor=(1.07,0.8))

# %%
plot_data_and_regress(hybrid,'accelrate','msrp')
# Out:
# Correlation, r:  0.695578
# Slope of Regression Line:     5068.0 y per x
# Intercept of Regression Line: -21282.0 y

# %%
def rmse(dataset,x,y):
    xdata, ydata = dataset.column(x), dataset.column(y)
    slp = np.round(slope(dataset,x,y))
    print('Slope of Regression Line:    ', slp, 'y per x')
    intercp = np.round(intercept(dataset,x,y))
    print('Intercept of Regression Line:', intercp, 'y')
    fitted = slp * xdata + intercp
    mse = np.mean((ydata - fitted) ** 2)
    print("Root mean squared error:", mse ** 0.5)

# %%
rmse(hybrid,'accelrate','msrp')
# Out:
# Slope of Regression Line:     5068.0 y per x
# Intercept of Regression Line: -21282.0 y
# Root mean squared error: 15339.646665465307

# %%
def lw_mse(any_slope, any_intercept):
    x = little_women.column('Periods')
    y = little_women.column('Characters')
    fitted = any_slope*x + any_intercept
    return np.mean((y - fitted) ** 2)

# %%
def lw_mse(any_slope,any_intercept):
    xdata, ydata = hybrid.column('accelrate'), hybrid.column('msrp')
    fitted = any_slope * xdata + any_intercept
    mse = np.mean((ydata - fitted) ** 2)
    print("Root mean squared error:", mse ** 0.5)
    return mse

# %%
best = minimize(lw_mse)
best
# Out:
# Root mean squared error: 44742.41246511989
# Root mean squared error: 44742.41246511989
# Root mean squared error: 44730.93086161264
# Root mean squared error: 44712.35417312308
# Root mean squared error: 42694.76716320163
# Root mean squared error: 16154.414690073761
# Root mean squared error: 65954.64303161329
# Root mean squared error: 16154.414690073761
# Root mean squared error: 29283.944542799352
# Root mean squared error: 22109.7271345521
# Root mean squared error: 16159.802158899083
# Root mean squared error: 16159.80215890118
# Root mean squared error: 16154.414690073761
# Root mean squared error: 16154.489358122675
# Root mean squared error: 16154.29400501366
# Root mean squared error: 16142.106262110585
# Root mean squared error: 16109.355972564987
# Root mean squared error: 16194.957069473361
# Root mean squared error: 16109.355972564987
# Root mean squared error: 16121.873322209747
# Root mean squared error: 16114.1383223109
# Root mean squared error: 16109.360484737557
# Root mean squared error: 16109.36048473781
# Root mean squared error: 42502.17969802435
# Root mean squared error: 16109.355972564987
# Root mean squared error: 42502.17969802435
# Root mean squared error: 68726.82703095801
# Root mean squared error: 16109.355972564987
# Root mean squared error: 30791.358856613053
# Root mean squared error: 21497.324636020658
# Root mean squared error: 16064.235792281195
# Root mean squared error: 16064.240310635423
# Root mean squared error: 16064.240310635425
# Root mean squared error: 16064.235792281195
# Root mean squared error: 16064.30854190659
# Root mean squared error: 16064.118212064765
# Root mean squared error: 16052.274584869741
# Root mean squared error: 16021.705619236232
# Root mean squared error: 16101.613291141766
# Root mean squared error: 16021.705619236232
# Root mean squared error: 16033.38880386669
# Root mean squared error: 16026.169203916226
# Root mean squared error: 16021.709877897852
# Root mean squared error: 16021.709877897869
# Root mean squared error: 16021.705619236232
# Root mean squared error: 15981.786130768043
# Root mean squared error: 16108.99610123978
# Root mean squared error: 15981.786130768043
# Root mean squared error: 16002.486956532792
# Root mean squared error: 15986.330999291187
# Root mean squared error: 15981.622791682123
# Root mean squared error: 15981.626804990885
# Root mean squared error: 15981.626804990885
# Root mean squared error: 15949.301372641881
# Root mean squared error: 15981.622791682123
# Root mean squared error: 15949.301372641881
# Root mean squared error: 16099.887939869495
# Root mean squared error: 15949.301372641881
# Root mean squared error: 15977.355399224032
# Root mean squared error: 15950.310641658774
# Root mean squared error: 15948.016162136397
# Root mean squared error: 15948.019526339904
# Root mean squared error: 15948.019526339904
# Root mean squared error: 15394.335717290422
# Root mean squared error: 15392.782871866408
# Root mean squared error: 15393.014217925565
# Root mean squared error: 15392.863505597265
# Root mean squared error: 15392.782805010243
# Root mean squared error: 15392.782862308797
# Root mean squared error: 15392.228444280983
# Root mean squared error: 15392.782805010243
# Root mean squared error: 15392.228444280983
# Root mean squared error: 15393.837603803577
# Root mean squared error: 15392.228444280983
# Root mean squared error: 15392.477463968495
# Root mean squared error: 15392.300527228286
# Root mean squared error: 15392.227857302702
# Root mean squared error: 15392.227912798471
# Root mean squared error: 15392.227912798471
# Root mean squared error: 15392.227857302702
# Root mean squared error: 15393.947236661255
# Root mean squared error: 15391.925699783493
# Root mean squared error: 15391.678695558412
# Root mean squared error: 15391.678695558412
# Root mean squared error: 15391.758818393184
# Root mean squared error: 15391.714733234028
# Root mean squared error: 15391.678750475567
# Root mean squared error: 15391.678750475567
# Root mean squared error: 15391.678695558412
# Root mean squared error: 15391.13532039671
# Root mean squared error: 15392.60704051755
# Root mean squared error: 15391.13532039671
# Root mean squared error: 15391.35448568506
# Root mean squared error: 15391.211857664512
# Root mean squared error: 15391.135259654633
# Root mean squared error: 15391.135313999182
# Root mean squared error: 15390.60910220673
# Root mean squared error: 15391.135259654633
# Root mean squared error: 15390.60910220673
# Root mean squared error: 15392.133096314663
# Root mean squared error: 15390.60910220673
# Root mean squared error: 15390.844673360116
# Root mean squared error: 15390.677701863431
# Root mean squared error: 15390.608568632193
# Root mean squared error: 15390.608621302195
# Root mean squared error: 15390.608621302197
# Root mean squared error: 15390.608568632193
# Root mean squared error: 15392.239289737323
# Root mean squared error: 15390.320949922203
# Root mean squared error: 15390.087256398927
# Root mean squared error: 15390.087256398927
# Root mean squared error: 15390.163315924476
# Root mean squared error: 15390.12135204356
# Root mean squared error: 15390.087308531032
# Root mean squared error: 15390.087308531032
# Root mean squared error: 15390.087256398927
# Root mean squared error: 15389.57132350144
# Root mean squared error: 15390.967736736831
# Root mean squared error: 15389.57132350144
# Root mean squared error: 15389.779188210656
# Root mean squared error: 15389.644050067349
# Root mean squared error: 15389.571268203206
# Root mean squared error: 15389.571319802893
# Root mean squared error: 15389.071343622929
# Root mean squared error: 15389.571268203206
# Root mean squared error: 15389.071343622929
# Root mean squared error: 15390.516356240187
# Root mean squared error: 15389.071343622929
# Root mean squared error: 15389.294461111183
# Root mean squared error: 15389.13669030318
# Root mean squared error: 15389.070857627312
# Root mean squared error: 15389.070907669182
# Root mean squared error: 15389.070907669182
# Root mean squared error: 15389.070857627312
# Root mean squared error: 15390.619198792581
# Root mean squared error: 15388.796820622509
# Root mean squared error: 15388.575454807076
# Root mean squared error: 15388.575454807076
# Root mean squared error: 15388.647734093884
# Root mean squared error: 15388.607751840787
# Root mean squared error: 15388.575504348155
# Root mean squared error: 15388.575504348155
# Root mean squared error: 15388.575454807076
# Root mean squared error: 15388.085060226156
# Root mean squared error: 15389.411458816518
# Root mean squared error: 15388.085060226156
# Root mean squared error: 15388.282424373383
# Root mean squared error: 15388.154236712107
# Root mean squared error: 15388.085009786711
# Root mean squared error: 15388.085058831994
# Root mean squared error: 15387.60952128798
# Root mean squared error: 15388.085009786711
# Root mean squared error: 15387.60952128798
# Root mean squared error: 15388.98117051467
# Root mean squared error: 15387.60952128798
# Root mean squared error: 15387.821087368176
# Root mean squared error: 15387.67182617817
# Root mean squared error: 15387.609077783107
# Root mean squared error: 15387.609125377045
# Root mean squared error: 15387.609125377043
# Root mean squared error: 15387.609077783107
# Root mean squared error: 15389.080756538438
# Root mean squared error: 15387.347744510325
# Root mean squared error: 15387.137814795307
# Root mean squared error: 15387.137814795307
# Root mean squared error: 15387.20657203384
# Root mean squared error: 15387.168443304601
# Root mean squared error: 15387.137861922329
# Root mean squared error: 15387.137861922329
# Root mean squared error: 15387.137814795307
# Root mean squared error: 15386.67122125232
# Root mean squared error: 15387.932428307568
# Root mean squared error: 15386.67122125232
# Root mean squared error: 15386.858813433104
# Root mean squared error: 15386.737085792833
# Root mean squared error: 15386.6711751716
# Root mean squared error: 15386.671223322213
# Root mean squared error: 15386.218178052828
# Root mean squared error: 15386.6711751716
# Root mean squared error: 15386.218178052828
# Root mean squared error: 15387.520445534405
# Root mean squared error: 15386.218178052828
# Root mean squared error: 15386.418673706296
# Root mean squared error: 15386.277786707575
# Root mean squared error: 15386.217785560166
# Root mean squared error: 15386.217830899794
# Root mean squared error: 15386.217830899794
# Root mean squared error: 15386.217785560166
# Root mean squared error: 15387.618161665976
# Root mean squared error: 15385.968118096005
# Root mean squared error: 15385.768906562065
# Root mean squared error: 15385.768906562065
# Root mean squared error: 15385.834397937379
# Root mean squared error: 15385.797971292164
# Root mean squared error: 15385.768951450622
# Root mean squared error: 15385.768951450622
# Root mean squared error: 15385.768906562065
# Root mean squared error: 15385.324391328506
# Root mean squared error: 15386.525822326856
# Root mean squared error: 15385.324391328506
# Root mean squared error: 15385.503083410618
# Root mean squared error: 15385.387144799539
# Root mean squared error: 15385.324347661124
# Root mean squared error: 15385.324393759209
# Root mean squared error: 15384.892631793902
# Root mean squared error: 15385.324347661124
# Root mean squared error: 15384.892631793902
# Root mean squared error: 15386.132470750126
# Root mean squared error: 15384.892631793902
# Root mean squared error: 15385.083412945572
# Root mean squared error: 15384.949509804854
# Root mean squared error: 15384.892265899322
# Root mean squared error: 15384.892309108107
# Root mean squared error: 15384.892309108107
# Root mean squared error: 15384.892265899322
# Root mean squared error: 15386.226540208621
# Root mean squared error: 15384.654052248889
# Root mean squared error: 15384.464426530314
# Root mean squared error: 15384.464426530314
# Root mean squared error: 15384.526848190657
# Root mean squared error: 15384.492092693798
# Root mean squared error: 15384.464469314844
# Root mean squared error: 15384.464469314844
# Root mean squared error: 15384.464426530314
# Root mean squared error: 15384.040667203377
# Root mean squared error: 15385.18541292888
# Root mean squared error: 15384.040667203377
# Root mean squared error: 15384.210876728011
# Root mean squared error: 15384.10052322604
# Root mean squared error: 15384.040626948703
# Root mean squared error: 15384.040672226913
# Root mean squared error: 15383.628582726375
# Root mean squared error: 15384.040626948703
