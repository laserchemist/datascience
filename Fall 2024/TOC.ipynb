# %% [markdown]
# ## Elements of Data Science for the Life and Physical Sciences
# ### Fall 2024

# %% [markdown]
# <img src="Temple_flag_morn.png" alt="Temple Powered" style="width: 200px;"/>

# %% [markdown]
# ## Resources
# - [Inferential Thinking Online Text](https://inferentialthinking.com/chapters/intro.html)
# - [Datascience Table Reference](http://data8.org/datascience/index.html)
# - [Data Science Primer BETA](https://laserchemist.github.io/dprimer/intro.html)
# - [EDS Course Website and Resources](https://sites.temple.edu/data/)
#
# ## Weekly Topics and Laboratory Links
# ### M1	Programming and data visualization
# 1. 	Course introduction &
# Python Bootcamp Week 1
# - Lab 00: [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab00/lab00_intro.ipynb) (Practice with Jupyter Notebooks)
# - Lab 01: [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab01/lab01_firstcode.ipynb) (Introduction to Python Coding)
#
# 2. 	Python Bootcamp Week 2
# (Data Types, Tables, Functions)
# (Data Types): Acceleration of Gravity on the Moon
# - Lab 02: updated [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab02/lab2_dataTypes.ipynb)
#
# 3. 	Understanding Data with Table Methods
# - Lab 03 [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab03/lab03_tables.ipynb)(Data Tables): Environmental Protection Index and Sustainability
#
# 4. 	Visualizing Data
# - Lab 04 [Link](http://localhost:8889/lab/tree/Documents/GitHub/datascience/Fall%202024/Lab04/Lab04-updated-2024-08-05.ipynb)(Functions and Visualization): COVID data
#
# 5.	Summary: Module 1
# - Mini-Project 1: Programming & Data Visualization: Olympics mini-project [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Mini%20Project%20I/Olympics_miniproject.ipynb)
#
#
# ### M2	Statistical inference
# 6. 	Iteration and Probability
# - Lab 05 [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab05/lab5_probability%20%26%20simulation-Fall-2024.ipynb) (Probability & Randomization): Groundhog Weather Prognostication
#
# 7. 	Hypothesis Testing (Sampling, Simulation)
# - Lab 06 [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab06/lab06_simulation-Fall-2024.ipynb)(Sampling & Simulation): DNA GC Content and Wordle
#
# 8. 	Inference & Causality
# - Lab 07 (Inference) [Link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab07/lab7_statistical_inference-update-2024-v2.ipynb):Global Climate Change
#
# 9. 	Summary: Module 2
# - Mini-Project 2: Statistical Inference: Mount Saint Helens and biodiversity recovery
#
# ### M3	Prediction and machine learning
# 10. 	Normal Distribution (Mean, Standard Deviation)
# - Lab 08 (Variance of Sample Means and Correlation): Old Faithful Eruption Data [link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab08/lab8_Variation%26Correlation.ipynb)
#
# 11. 	Regression & Regression Inference
# - Lab 09 (Regression): Estimation of the Age of the Universe [link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab09/lab09-AgeUniverse-Update-2024.ipynb)
#
# 12. 	Classifiers and Classification
# - Lab 10 (Machine Learning, Classification, & Chemistry): Flower species classification and Molecular Acidity Prediction [link](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Lab10/Machine%20Learning%20and%20Chemistry.ipynb)
#
# 13. 	Group Projects:
# - [Suggested Data Sets](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Group-project/dataset.ipynb)
# - [Example Project](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Group-project/example_group_project-indego_bikes/Indego.ipynb)
# - [Project Details](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/datascience/Fall%202024/Group-project/Group_Project_Spring2024)
#
# 14. 	Project Presentations
# - Group Project Presentations
