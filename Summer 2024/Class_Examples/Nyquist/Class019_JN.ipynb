# %% [markdown]
# ### Hypothesis testing
# #### Mini project II
# Elements of Data Science

# %%
import numpy as np
from datascience import *

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Fix for datascience plots
import collections as collections
import collections.abc as abc
collections.Iterable = abc.Iterable

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# #### Create differences Test statistic

# %%
def diff_n(values, n):
    return np.array(values)[n:] - np.array(values)[:-n]

# %%
positive = np.count_nonzero(diff_n(make_array(1.0, 1.5,1.4, 1.2, 2.0, 1.8), 2)>0)
positive
# Out:
# 3

# %%
negative = np.count_nonzero(diff_n(make_array(1.0, 1.5,1.4, 1.2, 2.0, 1.8), 2) < 0)
negative
# Out:
# 1

# %%
positive - negative
# Out:
# 2

# %%
def changes(rates, years = 1):
    "Return the number of increases minus the number of decreases after two years."
    differences = diff_n(rates, years)  
    positives = np.count_nonzero(differences > 0)
    negatives = np.count_nonzero(differences < 0) 
    return positives - negatives

# %% [markdown]
# ### Inference and biodiversity recovery

# %%
# Plot description dataset
# For the project, you will pick two plot codes
# This first file has important metadata about the plots
datafile = "../Mini-II/data/MSH_PLOT_DESCRIPTORS2.csv"
MSH_PLOT = Table.read_table(datafile)
MSH_PLOT
# Out:
# PLOT_NAME      | PLOT_CODE | FIRST_YEAR | LAST_YEAR | UTMGRID | UTMEAST | UTMNORTH | LONG    | LAT     | POT._RAD. | HEAT_LOAD | ELEVATION(M) | ASPECT | SLOPE | IMPACT_TYPE | SUCCESSION_TYPE
# Toutle Ridge10 | TORD10    | 1981       | 1996      | 10T     | 559724  | 5118180  | 122.226 | 46.2146 | 0.769     | 0.796     | 1430         | N      | 11    | Blast edge  | Secondary
# Toutle Ridge09 | TORD09    | 1981       | 1997      | 10T     | 559599  | 5118216  | 122.227 | 46.2149 | 0.722     | 0.827     | 1417         | NW     | 18    | Blast edge  | Secondary
# Toutle Ridge08 | TORD08    | 1981       | 1997      | 10T     | 559565  | 5118281  | 122.228 | 46.2155 | 0.788     | 0.833     | 1401         | NNW    | 10    | Blast edge  | Secondary
# Toutle Ridge07 | TORD07    | 1981       | 1997      | 10T     | 559466  | 5118302  | 122.229 | 46.2157 | 0.756     | 0.786     | 1379         | N      | 12    | Blast edge  | Secondary
# Toutle Ridge06 | TORD06    | 1981       | 1997      | 10T     | 559413  | 5118329  | 122.23  | 46.2159 | 0.835     | 0.877     | 1365         | NW     | 7     | Blast edge  | Secondary
# Toutle Ridge05 | TORD05    | 1981       | 1997      | 10T     | 559342  | 5118366  | 122.231 | 46.2163 | 0.822     | 0.854     | 1352         | NNW    | 7     | Blast edge  | Secondary
# Toutle Ridge04 | TORD04    | 1981       | 1997      | 10T     | 559279  | 5115125  | 122.232 | 46.1871 | 0.764     | 0.818     | 1340         | NNW    | 12    | Blast edge  | Secondary
# Toutle Ridge03 | TORD03    | 1981       | 1997      | 10T     | 559238  | 5118483  | 122.232 | 46.2173 | 0.764     | 0.818     | 1320         | NNW    | 12    | Blast edge  | Secondary
# Toutle Ridge02 | TORD02    | 1981       | 1997      | 10T     | 559091  | 5118480  | 122.234 | 46.2173 | 0.861     | 0.9       | 1294         | WNW    | 6     | Blast edge  | Secondary
# Toutle Ridge01 | TORD01    | 1981       | 1997      | 10T     | 558992  | 5118569  | 122.235 | 46.2181 | 0.874     | 0.9       | 1280         | WNW    | 4     | Blast edge  | Secondary
# ... (82 rows omitted)

# %%
np.unique(MSH_PLOT['PLOT_CODE'])
# Out:
# array(['ABPL01', 'ABPL02', 'ABPL03', 'ABPL04', 'ABPL05', 'ABPL06',
#        'ABPL07', 'ABPL08', 'ABPL09', 'ABPL10', 'BUCA01', 'BUCA03',
#        'BUCA04', 'BUCB01', 'BUCB02', 'BUCB03', 'BUCB04', 'BUCB05',
#        'BUCB06', 'BUCB07', 'BUCC01', 'BUCC02', 'BUCC03', 'BUCD01',
#        'BUCD02', 'BUCD03', 'BUCD05', 'LAH04', 'LAH05', 'LAH06', 'LAH07',
#        'LAH08', 'LAHR01', 'LAHR02', 'PICA01', 'PICA02', 'PICA03', 'PICA04',
#        'PICB01', 'PICB02', 'PICB03', 'PICB04', 'PICB05', 'PICE02',
#        'PICE03', 'PICE04', 'PUPL01', 'PUPL02', 'PUPL03', 'PUPL04',
#        'PUPL05', 'PUPL06', 'PUPL07', 'PUPL08', 'PUPL09', 'PUPL10',
#        'PUPL11', 'PUPL12', 'SFTR01', 'SFTR02', 'SFTR03', 'SFTR04',
#        'STRD01', 'STRD02', 'STRD03', 'STRD04', 'STRD05', 'STRD06',
#        'STRD07', 'STRD08', 'STRD09', 'STRD10', 'STRD11', 'STRD12',
#        'STRD13', 'STRD14', 'STRD15', 'STRD16', 'STRD17', 'STRD18',
#        'STRD19', 'STRD20', 'TORD01', 'TORD02', 'TORD03', 'TORD04',
#        'TORD05', 'TORD06', 'TORD07', 'TORD08', 'TORD09', 'TORD10'],
#       dtype='<U6')

# %%
MSH_PLOT = MSH_PLOT.with_columns('NLONG',-1*(MSH_PLOT.column('LONG')))
MSH_map = MSH_PLOT.select('LAT', 'NLONG', 'PLOT_CODE').relabel('PLOT_CODE', 'labels')
Circle.map_table(MSH_map, color='blue',area=200)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_003cb105d570d383c29d614f7b767832 {
#                     position: relative;
#                     width: 960.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_003cb105d570d383c29d614f7b767832&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_003cb105d570d383c29d614f7b767832 = L.map(
#                 &quot;map_003cb105d570d383c29d614f7b767832&quot;,
#                 {
#                     center: [46.19464, -122.18735000000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     clusteredMarker: false,
#                     includeColorScaleOutliers: true,
#                     radiusInMeters: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6d8dab115cdfdc145ce43dec5db96f2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 17, &quot;maxZoom&quot;: 17, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_003cb105d570d383c29d614f7b767832);
#
#
#             var circle_marker_143168d4c50b6696d9592a012eb84fe6 = L.circleMarker(
#                 [46.21457, -122.22569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.978845608028654, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_003cb105d570d383c29d614f7b767832);
#
#
#         var popup_288bb9c8b0c06521d6e518c7de74cd9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b3991720492987339d3a1f911c9fb01 = $(`&lt;div id=&quot;html_4b3991720492987339d3a1f911c9fb01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TORD10&lt;/div&gt;`)[0];
#                 popup_288bb9c8b0c06521d6e518c7de74cd9d.setContent(html_4b3991720492987339d3a1f911c9fb01);
#
#
#
#         circle_marker_143168d4c50b6696d9592a012eb84fe6.bindPopup(popup_288bb9c8b0c06521d6e518c7de74cd9d)
#         ;
#
#
#
#
#             var circle_marker_a9d7a6dea337a3cf73dc4e734e6cb17a = L.circleMarker(
#                 [46.21491, -122.22731],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.978845608028654, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_003cb105d570d383c29d614f7b767832);
#
#
#         var popup_a0cb5beb979d9fec6884ddd909b82f6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3655b0a085930834e35db610d46ccf8d = $(`&lt;div id=&quot;html_3655b0a085930834e35db610d46ccf8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TORD09&lt;/div&gt;`)[0];
#                 popup_a0cb5beb979d9fec6884ddd909b82f6d.setContent(html_3655b0a085930834e35db610d46ccf8d);
#
#
#
#         circle_marker_a9d7a6dea337a3cf73dc4e734e6cb17a.bindPopup(popup_a0cb5beb979d9fec6884ddd909b82f6d)
#         ;
#
#
#
#
#             var circle_marker_b1384634797bf7a4412b3d16bc053488 = L.circleMarker(
#                 [46.2155, -122.22774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.978845608028654, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_003cb105d570d383c29d614f7b767832);
#
#
#         var popup_3882fe8b6b07cdc52e096e403af738dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12bfc8cb3293036353a0338f3f8153be = $(`&lt;div id=&quot;html_12bfc8cb3293036353a0338f3f8153be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TORD08&lt;/div&gt;`)[0];
#                 popup_3882fe8b6b07cdc52e096e403af738dd.setContent(html_12bfc8cb3293036353a0338f3f8153be);
#
#
#
#         circle_marker_b1384634797bf7a4412b3d16bc053488.bindPopup(popup_3882fe8b6b07cdc52e096e403af738dd)
#         ;
#
#
#
#
#             var circle_marker_323de94541fb4b0bf75ec7e28aaefedb = L.circleMarker(
#                 [46.21569, -122.22902],

# %% [markdown]
# ## How can we join these data sets?

# %%
# Load plot data by year
datafile = "../Mini-II/data/MSH_STRUCTURE_PLOT_YEAR.csv"
MSH_YEAR = Table.read_table(datafile)
MSH_YEAR.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLOT_ID</th> <th>PLOT_NAME</th> <th>PLOT_NUMBER</th> <th>YEAR</th> <th>RICHNESS</th> <th>COVER_%</th> <th>HPRIME</th> <th>EVENNESS</th> <th>FREQUENCY</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ABPL011995</td> <td>ABPL     </td> <td>1          </td> <td>1995</td> <td>14      </td> <td>2.2    </td> <td>2.41  </td> <td>0.913   </td> <td>7.7      </td>
#         </tr>
#         <tr>
#             <td>ABPL011996</td> <td>ABPL     </td> <td>1          </td> <td>1996</td> <td>17      </td> <td>2.9    </td> <td>2.524 </td> <td>0.891   </td> <td>8.1      </td>
#         </tr>
#         <tr>
#             <td>ABPL011997</td> <td>ABPL     </td> <td>1          </td> <td>1997</td> <td>18      </td> <td>4.2    </td> <td>2.231 </td> <td>0.772   </td> <td>11.6     </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1740 rows omitted)</p>

# %%
MSH_PLOT.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLOT_NAME</th> <th>PLOT_CODE</th> <th>FIRST_YEAR</th> <th>LAST_YEAR</th> <th>UTMGRID</th> <th>UTMEAST</th> <th>UTMNORTH</th> <th>LONG</th> <th>LAT</th> <th>POT._RAD.</th> <th>HEAT_LOAD</th> <th>ELEVATION(M)</th> <th>ASPECT</th> <th>SLOPE</th> <th>IMPACT_TYPE</th> <th>SUCCESSION_TYPE</th> <th>NLONG</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Toutle Ridge10</td> <td>TORD10   </td> <td>1981      </td> <td>1996     </td> <td>10T    </td> <td>559724 </td> <td>5118180 </td> <td>122.226</td> <td>46.2146</td> <td>0.769    </td> <td>0.796    </td> <td>1430        </td> <td>N     </td> <td>11   </td> <td>Blast edge </td> <td>Secondary      </td> <td>-122.226</td>
#         </tr>
#         <tr>
#             <td>Toutle Ridge09</td> <td>TORD09   </td> <td>1981      </td> <td>1997     </td> <td>10T    </td> <td>559599 </td> <td>5118216 </td> <td>122.227</td> <td>46.2149</td> <td>0.722    </td> <td>0.827    </td> <td>1417        </td> <td>NW    </td> <td>18   </td> <td>Blast edge </td> <td>Secondary      </td> <td>-122.227</td>
#         </tr>
#         <tr>
#             <td>Toutle Ridge08</td> <td>TORD08   </td> <td>1981      </td> <td>1997     </td> <td>10T    </td> <td>559565 </td> <td>5118281 </td> <td>122.228</td> <td>46.2155</td> <td>0.788    </td> <td>0.833    </td> <td>1401        </td> <td>NNW   </td> <td>10   </td> <td>Blast edge </td> <td>Secondary      </td> <td>-122.228</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (89 rows omitted)</p>

# %%
test = 'ABPL011995'
test[0:6]
# Out:
# 'ABPL01'

# %%
# lambda functions

chop_six = lambda x: x[0:6]

# %%
chop_six("What are the first six characters of this string?")
# Out:
# 'What a'

# %%
# This function is equivalent to the lambda function above.
def chop_six_v2(str):
    return str[0:6]

chop_six_v2("What are the first six characters of this string?")
# Out:
# 'What a'

# %%
MSH_YEAR = MSH_YEAR.with_column('PLOT_CODE',MSH_YEAR.apply(lambda x: x[0:6], 'PLOT_ID'))
MSH_YEAR.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLOT_ID</th> <th>PLOT_NAME</th> <th>PLOT_NUMBER</th> <th>YEAR</th> <th>RICHNESS</th> <th>COVER_%</th> <th>HPRIME</th> <th>EVENNESS</th> <th>FREQUENCY</th> <th>PLOT_CODE</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ABPL011995</td> <td>ABPL     </td> <td>1          </td> <td>1995</td> <td>14      </td> <td>2.2    </td> <td>2.41  </td> <td>0.913   </td> <td>7.7      </td> <td>ABPL01   </td>
#         </tr>
#         <tr>
#             <td>ABPL011996</td> <td>ABPL     </td> <td>1          </td> <td>1996</td> <td>17      </td> <td>2.9    </td> <td>2.524 </td> <td>0.891   </td> <td>8.1      </td> <td>ABPL01   </td>
#         </tr>
#         <tr>
#             <td>ABPL011997</td> <td>ABPL     </td> <td>1          </td> <td>1997</td> <td>18      </td> <td>4.2    </td> <td>2.231 </td> <td>0.772   </td> <td>11.6     </td> <td>ABPL01   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1740 rows omitted)</p>

# %%
# Join the two datatables on their common feature
volcano = MSH_PLOT.join('PLOT_CODE', MSH_YEAR, 'PLOT_CODE')
volcano.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLOT_CODE</th> <th>PLOT_NAME</th> <th>FIRST_YEAR</th> <th>LAST_YEAR</th> <th>UTMGRID</th> <th>UTMEAST</th> <th>UTMNORTH</th> <th>LONG</th> <th>LAT</th> <th>POT._RAD.</th> <th>HEAT_LOAD</th> <th>ELEVATION(M)</th> <th>ASPECT</th> <th>SLOPE</th> <th>IMPACT_TYPE</th> <th>SUCCESSION_TYPE</th> <th>NLONG</th> <th>PLOT_ID</th> <th>PLOT_NAME_2</th> <th>PLOT_NUMBER</th> <th>YEAR</th> <th>RICHNESS</th> <th>COVER_%</th> <th>HPRIME</th> <th>EVENNESS</th> <th>FREQUENCY</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>ABPL01   </td> <td>Abraham Plain01</td> <td>1995      </td> <td>2009     </td> <td>10T    </td> <td>566370 </td> <td>5118007 </td> <td>122.14</td> <td>46.2124</td> <td>0.893    </td> <td>0.881    </td> <td>1365        </td> <td>E     </td> <td>2    </td> <td>Blast; Scour; Pumice</td> <td>Primary        </td> <td>-122.14</td> <td>ABPL011995</td> <td>ABPL       </td> <td>1          </td> <td>1995</td> <td>14      </td> <td>2.2    </td> <td>2.41  </td> <td>0.913   </td> <td>7.7      </td>
#         </tr>
#         <tr>
#             <td>ABPL01   </td> <td>Abraham Plain01</td> <td>1995      </td> <td>2009     </td> <td>10T    </td> <td>566370 </td> <td>5118007 </td> <td>122.14</td> <td>46.2124</td> <td>0.893    </td> <td>0.881    </td> <td>1365        </td> <td>E     </td> <td>2    </td> <td>Blast; Scour; Pumice</td> <td>Primary        </td> <td>-122.14</td> <td>ABPL011996</td> <td>ABPL       </td> <td>1          </td> <td>1996</td> <td>17      </td> <td>2.9    </td> <td>2.524 </td> <td>0.891   </td> <td>8.1      </td>
#         </tr>
#         <tr>
#             <td>ABPL01   </td> <td>Abraham Plain01</td> <td>1995      </td> <td>2009     </td> <td>10T    </td> <td>566370 </td> <td>5118007 </td> <td>122.14</td> <td>46.2124</td> <td>0.893    </td> <td>0.881    </td> <td>1365        </td> <td>E     </td> <td>2    </td> <td>Blast; Scour; Pumice</td> <td>Primary        </td> <td>-122.14</td> <td>ABPL011997</td> <td>ABPL       </td> <td>1          </td> <td>1997</td> <td>18      </td> <td>4.2    </td> <td>2.231 </td> <td>0.772   </td> <td>11.6     </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1524 rows omitted)</p>

# %%
np.unique(volcano['IMPACT_TYPE'])
# Out:
# array(['Blast', 'Blast edge', 'Blast; Scour; Pumice', 'Blast; pumice',
#        'Lahar-thick deposit', 'Scour-Mild',
#        'Scour-intense; Moderate deposit', 'Scour-moderate; Thin deposit',
#        'Tephra', 'Weak blast; tephra'],
#       dtype='<U31')

# %% [markdown]
# 1. Create initial data tables and plots to explore the nature of the different plots included in "data/MSH_PLOT_DESCRIPTORS2.csv". Variables to consider include elevation, slope, aspect (direction), impact type. You could use group or pivot methods here.
#
# 2. Identify two PLOT_CODEs to study based on mapped location and characteristics given in "data/MSH_PLOT_DESCRIPTORS2.csv" file. Use a markdown cell to provide reasons for your two choices of plots. Include differences and similarities.
#
# 3. Carry out exploratory data analysis on the yearly data included in "data/MSH_STRUCTURE_PLOT_YEAR.csv" for each of the identified plots.

# %% [markdown]
# ## Some example data exploration
# ### Richness vs. aspect -- a decade of change

# %%
np.unique(volcano['FIRST_YEAR'])
# Out:
# array([1980, 1981, 1982, 1984, 1989, 1995])

# %%
np.unique(volcano['LAST_YEAR'])
# Out:
# array([1980, 1990, 1996, 1998, 2005, 2008, 2009])

# %%
before = volcano.where('YEAR', 1990)
after = volcano.where('YEAR', 2000)

before.select('ASPECT', 'RICHNESS', 'COVER_%').group('ASPECT')
# Out:
# ASPECT | count
# E      | 2
# ENE    | 2
# ESE    | 5
# N      | 3
# N      | 5
# NE     | 9
# NNE    | 3
# NW     | 12
# S      | 2
# SE     | 3
# ... (4 rows omitted)

# %%
after.select('ASPECT', 'RICHNESS', 'COVER_%').group('ASPECT')
# Out:
# ASPECT | count
# E      | 11
# ESE    | 3
# N      | 2
# N      | 4
# NE     | 9
# NNE    | 2
# NW     | 12
# S      | 2
# SE     | 3
# SSW    | 1
# ... (2 rows omitted)

# %% [markdown]
# ## There is always a data cleaning issue!
# There direction north is sometime encoded as 'N' and sometimes as 'N '

# %%
np.unique(volcano['ASPECT'])
# Out:
# array(['E', 'ENE', 'ESE', 'N', 'N ', 'NE', 'NNE', 'NW', 'S', 'SE', 'SSW',
#        'SW', 'W', 'WSW'],
#       dtype='<U3')

# %%
# Fix the problem
aspect = volcano.column('ASPECT')
aspect[np.nonzero(aspect == 'N ')] = 'N'
volcano = volcano.with_columns('ASPECT', aspect)

before = volcano.where('YEAR', 1990)
after = volcano.where('YEAR', 2000)

before.select('ASPECT', 'RICHNESS', 'COVER_%').group('ASPECT')
# Out:
# ASPECT | count
# E      | 2
# ENE    | 2
# ESE    | 5
# N      | 8
# NE     | 9
# NNE    | 3
# NW     | 12
# S      | 2
# SE     | 3
# SSW    | 2
# ... (3 rows omitted)

# %%
after.select('ASPECT', 'RICHNESS', 'COVER_%').group('ASPECT')
# Out:
# ASPECT | count
# E      | 11
# ESE    | 3
# N      | 6
# NE     | 9
# NNE    | 2
# NW     | 12
# S      | 2
# SE     | 3
# SSW    | 1
# SW     | 2
# ... (1 rows omitted)

# %%
before.select('ASPECT', 'RICHNESS', 'COVER_%').group('ASPECT', np.median)
# Out:
# ASPECT | RICHNESS median | COVER_% median
# E      | 9.5             | 22.05
# ENE    | 20              | 72.85
# ESE    | 11              | 19.5
# N      | 7               | 1
# NE     | 5               | 0.5
# NNE    | 7               | 0.7
# NW     | 6.5             | 0.75
# S      | 18.5            | 33.05
# SE     | 13              | 27.7
# SSW    | 20              | 40.9
# ... (3 rows omitted)

# %%
after.select('ASPECT', 'RICHNESS', 'COVER_%').group('ASPECT', np.median)
# Out:
# ASPECT | RICHNESS median | COVER_% median
# E      | 17              | 6.1
# ESE    | 12              | 28.8
# N      | 18              | 47.3
# NE     | 19              | 3.5
# NNE    | 20.5            | 35.05
# NW     | 19.5            | 7.05
# S      | 20.5            | 35.2
# SE     | 16              | 40.6
# SSW    | 19              | 52.2
# SW     | 19.5            | 39.2
# ... (1 rows omitted)

# %%
before = before.select('ASPECT', 'RICHNESS')
after = after.select('ASPECT', 'RICHNESS')
before.join('ASPECT', after, 'ASPECT').group('ASPECT', np.median)
# Out:
# ASPECT | RICHNESS median | RICHNESS_2 median
# E      | 9.5             | 17
# ESE    | 11              | 12
# N      | 7               | 18
# NE     | 5               | 19
# NNE    | 7               | 20.5
# NW     | 6.5             | 19.5
# S      | 18.5            | 20.5
# SE     | 13              | 16
# SSW    | 20              | 19
# SW     | 20              | 19.5
# ... (1 rows omitted)

# %% [markdown]
# # Let's look at some trends

# %%
np.unique(MSH_YEAR['PLOT_NAME'])
# Out:
# array(['ABPL', 'BUCA', 'BUCB', 'BUCC', 'BUCD', 'LAHR', 'PICA', 'PICB',
#        'PICE', 'PUPL', 'SFTR', 'STRD', 'TORD'],
#       dtype='<U4')

# %%
MSH_YEAR.where('PLOT_NAME','STRD').scatter("YEAR","RICHNESS")

# %%
MSH_YEAR.where('PLOT_NAME','STRD').group("YEAR",np.mean)
# Out:
# YEAR | PLOT_ID mean | PLOT_NAME mean | PLOT_NUMBER mean | RICHNESS mean | COVER_% mean | HPRIME mean | EVENNESS mean | FREQUENCY mean
# 1984 |              |                | 5.5              | 0.6           | 0.06         | 0.1386      | 0.2           | 1.1
# 1985 |              |                | 5.5              | 0.8           | 0.08         | 0.2079      | 0.3           | 0.85
# 1986 |              |                | 5.5              | 1.4           | 0.28         | 0.3871      | 0.4           | 3.23
# 1988 |              |                | 5.5              | 3.6           | 1.45         | 0.9923      | 0.5882        | 9.66
# 1989 |              |                | 10.5             | 4.7           | 3.295        | 1.2956      | 0.82585       | 3.51
# 1990 |              |                | 10.5             | 6.25          | 1.435        | 1.6168      | 0.919         | 3.605
# 1991 |              |                | 10.5             | 8.3           | 3.11         | 1.79715     | 0.88635       | 3.87
# 1992 |              |                | 10.5             | 11.15         | 4.71         | 2.0761      | 0.87865       | 4.43
# 1993 |              |                | 8.5              | 13.375        | 6.40625      | 2.11463     | 0.830813      | 7.1
# 1994 |              |                | 10.5             | 13.1          | 7.435        | 2.11255     | 0.83115       | 8.25
# ... (14 rows omitted)

# %%
MSH_YEAR.where('PLOT_NAME','STRD').group("YEAR",np.mean).scatter("YEAR", "RICHNESS mean")

# %%
MSH_YEAR.where('PLOT_NAME','STRD').scatter('YEAR','RICHNESS')

# %%
def simulate_under_null(num_chances_to_change):
    uniform = Table().with_columns(
        "Change", make_array('Increase', 'Decrease'),
        "Chance", make_array(0.5,        0.5))
    sample = uniform.sample_from_distribution('Chance', num_chances_to_change)     
    increases = sample.column("Chance sample").item(0) 
    decreases = sample.column("Chance sample").item(1)  
    return increases - decreases

# %%
def empirical_distribution(tbl,iterations):
    num_changes = tbl.num_rows 
    samples = make_array()
    for i in np.arange(iterations):
        samples = np.append(samples, simulate_under_null(num_changes)) 
    Table().with_column('Test statistic under null', samples).hist(bins=np.arange(min(samples), max(samples) + max(samples) , 2))
    return samples

# %%
empirical_distribution(MSH_YEAR.where('PLOT_NAME','STRD').group("YEAR",np.mean),10000)
# Out:
# array([  4.,  10.,   0., ...,   8.,   2.,   4.])

# %%
empirical_distribution(MSH_YEAR.where('PLOT_NAME','STRD'),10000)
# Out:
# array([ -9.,  -1.,  -5., ..., -35.,  19.,  41.])
