# %% [markdown]
# # Momma Tables.where() and all her little predicates
#
# Filtering datatables is done withe the .where() method for which there are a whole slew of "predicates" that indicate the filtering condition. As always, you learn best by practicing.

# %%
# Load the required modules
import numpy as np
from datascience import *

# %% [markdown]
# ## Philadelphia Services
# To keep things interesting, we'll take a look at a dataset available on [OpenDataPhilly](https://opendataphilly.org/datasets/) that contains services available in the city.

# %%
path = 'data/'
data = path + "philly_services.csv"
services = Table.read_table(data)
services
# Out:
# Id   | Category              | Organization Name                                 | Address                                       | Zip Code | Days                                                         | Time: Open | Time: Close | People Served              | Description                                                  | Phone Number    | LatLon
# 1    | Day / Drop in Centers | A New Life Recovery & Education Center            | 3119 Spring Garden St, Philadelphia, PA 19104 | 19104    | Tues-Sat: 10-6pm Recovery & peer support; 1-3pm Snacks W ... | 10PM       | 6PM         | Women, Men, Families       | Services provided: Recovery & peer support, Snacks, Laun ... | 267-507-3529    | -75.18833430000001,39.9635841
# 2    | Emergency Shelter     | ACTS Christian Transistional Services             | 1428 N. 28th St, Philadelphia, PA 19121       | 19121    | 2nd, 3rd, 4th Wednesdays, 6-9 PM                             | 6PM        | 9PM         | Women, Women with Children | ACTS is a recovery house for women and their children pr ... | (215) 769-9799  | -75.1812997,39.97794469999999
# 3    | Emergency Shelter     | Apple Tree Family Center                          | 1430 Cherry St, Philadelphia, PA 19102        | 19102    | Mon-Fri 7AM - 3PM                                            | nan        | nan         | Women, Families            | Families/Single Women Seeking Emergency Housing Services ... | 215-686-7150/52 | -75.1641606,39.9554759
# 4    | Emergency Food        | Grace Café at Arch Street United Methodist Church | 55 N Broad St, Philadelphia, PA 19107         | 19107    | Sunday 5:30PM - 7PM                                          | 5:30 PM    | 7:00 PM     | Women, Men, Families       | Dinner Sun: 5:30-7:00pm                                      | 215-568-6250    | -75.16290719999999,39.954096
# 5    | Permanent Housing     | Bethesda Bainbridge                               | 700 S. 15th St, Philadelphia, PA 19146        | 19146    | nan                                                          | nan        | nan         | Men                        | Permanent single room occupancy (SRO) housing for 30 men ... | (215) 985-1600  | -75.167497,39.9429167
# 6    | Permanent Housing     | Bethesda North Broad                              | 722 N. Broad St, Philadelphia, PA 19130       | 19130    | nan                                                          | nan        | nan         | Women                      | Permanent SRO housing for 49 men and women with historie ... | (215) 985-1600  | -75.1605817,39.9678332
# 7    | Permanent Housing     | Bethesda Spruce                                   | 1110 Spruce St Philadelphia, PA 19107         | 19107    | nan                                                          | nan        | nan         | Women                      | Permanent SRO housing for 16 women who cope with chronic ... | (215) 985-1600  | -75.16005419999999,39.94611099999999
# 8    | Emergency Food        | Bright Hope Baptist Church                        | 1601 N 12th St, Philadelphia, PA 19122        | 19122    | Mon - Thurs (6PM-6:45PM) & Sat (11AM-12PM)                   | 6:00 PM    | 6:45 PM     | Women, Men, Families       | Monday-Thursday meals closed July and August; clothing,  ... | 215-232-6004    | -75.1540249,39.978021
# 9    | Emergency Food        | Breaking Bread at Broad Street Ministry           | 315 S. Broad Street Philadelphia, PA 19107    | 19107    | Breakfast Mon: 7:45-8:45am Lunch Thurs & Fri: 11:30-12:1 ... | nan        | nan         | Women, Men, Families       | BSM’s Breaking Bread meals are open to anyone who wishes ... | 215-735-4847    | -75.1644824,39.9461067
# 10   | Emergency Shelter     | Philadelphia Brotherhood Rescue Mission (PBRM)    | 401 E. Girard Avenue, Philadelphia, PA 19125  | 19125    | Mon to Sun, 6:30 AM to 12:00 AM Open 24 hours for emerge ... | 24 hours   | nan         | Men                        | Established in 1908, PBRM serves the homeless, the needy ... | 866-HOPE-4-MEN  | -75.13049199999999,39.9704849
# ... (91 rows omitted)

# %% [markdown]
# ## Predicates
# The .where() method of datatables takes a variety of "predicates," which are express the condition you wish to use to filter the data.

# %% [markdown]
# ## Services in the Temple zip code
#
# Temple's zip code ia 19122. Let's find the services within the Temple zip code.
#
# The general format of the .where() methods is .where(column_name, predicate), so we want to filter on the 'Zip Code' column and use the predicate are.equal_to(). A new table is returned with just the rows that match our condition.

# %%
temple_zipcode = services.where('Zip Code', are.equal_to(19122))
temple_zipcode
# Out:
# Id   | Category          | Organization Name          | Address                                      | Zip Code | Days                                       | Time: Open | Time: Close | People Served        | Description                                                  | Phone Number | LatLon
# 8    | Emergency Food    | Bright Hope Baptist Church | 1601 N 12th St, Philadelphia, PA 19122       | 19122    | Mon - Thurs (6PM-6:45PM) & Sat (11AM-12PM) | 6:00 PM    | 6:45 PM     | Women, Men, Families | Monday-Thursday meals closed July and August; clothing,  ... | 215-232-6004 | -75.1540249,39.978021
# 20   | Emergency Shelter | Drueding Center            | 413 W. Master Street, Philadelphia, PA 19122 | 19122    | nan                                        | nan        | nan         | Women, Families      | As the first Philadelphia program to provide both transi ... | nan          | -75.14305809999999,39.97259469999999
# 50   | Emergency Food    | Mt. Olive Holy Temple      | 1469 N Broad St, Philadelphia, PA 19122      | 19122    | Tuesday                                    | 12:00 PM   | 2:00 PM     | Women, Men, Families | Lunch Tues: 12-2pm                                           | 215-765-3372 | -75.1580833,39.9756058

# %% [markdown]
# **Challenge:** Try finding all services with a zipcode of 19107

# %% [markdown]
# ## Looking for Food Services
# Now suppose we wanted all the services where "Food" is part of the Category column. We need a different predicate. are.containing() works when the specified column contains strings and looks to see if it contains the desired substring. To see if the text in the "Category" column contains the subtring "Food" we do this:

# %%
food = services.where('Category', are.containing("Food"))
food
# Out:
# Id   | Category       | Organization Name                                 | Address                                              | Zip Code | Days                                                         | Time: Open | Time: Close | People Served              | Description                                                  | Phone Number   | LatLon
# 4    | Emergency Food | Grace Café at Arch Street United Methodist Church | 55 N Broad St, Philadelphia, PA 19107                | 19107    | Sunday 5:30PM - 7PM                                          | 5:30 PM    | 7:00 PM     | Women, Men, Families       | Dinner Sun: 5:30-7:00pm                                      | 215-568-6250   | -75.16290719999999,39.954096
# 8    | Emergency Food | Bright Hope Baptist Church                        | 1601 N 12th St, Philadelphia, PA 19122               | 19122    | Mon - Thurs (6PM-6:45PM) & Sat (11AM-12PM)                   | 6:00 PM    | 6:45 PM     | Women, Men, Families       | Monday-Thursday meals closed July and August; clothing,  ... | 215-232-6004   | -75.1540249,39.978021
# 9    | Emergency Food | Breaking Bread at Broad Street Ministry           | 315 S. Broad Street Philadelphia, PA 19107           | 19107    | Breakfast Mon: 7:45-8:45am Lunch Thurs & Fri: 11:30-12:1 ... | nan        | nan         | Women, Men, Families       | BSM’s Breaking Bread meals are open to anyone who wishes ... | 215-735-4847   | -75.1644824,39.9461067
# 11   | Emergency Food | Philadelphia Brotherhood Rescue Mission (PBRM)    | 401 E. Girard Avenue, Philadelphia, PA 19125         | 19125    | Mon to Sun, 6:30 AM to 12:00 AM Open 24 hours for emerge ... | 6:30AM     | 12:00AM     | Men                        | Established in 1908, PBRM serves the homeless, the needy ... | 866-HOPE-4-MEN | -75.13049199999999,39.9704849
# 12   | Emergency Food | Chosen 300 Outreach Center                        | 1116 Spring Garden St, Philadelphia, PA 19123        | 19123    | Mon: 6:00PM, Wed: 6:00PM, Fri: 6:00PM, Sat: 5:00PM, Sun: ... | 6:00PM     | nan         | Women, Men, Families       | When the economy is impacted, companies pull back from c ... | 215-765-9806   | -75.1569384,39.961445
# 13   | Emergency Food | Chosen 300 Outreach Center                        | 16th & Ben Franklin Parkway, Philadelphia, PA 19103  | 19103    | Sat: 5:00PM                                                  | 5:00PM     | nan         | Women, Men, Families       | When the economy is impacted, companies pull back from c ... | nan            | -75.1663793,39.9547511
# 14   | Emergency Food | Chosen 300 Outreach Center                        | 3959 Lancaster Ave, Philadelphia, PA 19104           | 19104    | Sun: 10:00AM, Mon: 6:00PM, Fri: 6:00PM                       | 6:00PM     | nan         | Women, Men, Families       | When the economy is impacted, companies pull back from c ... | nan            | -75.20195199999999,39.96317
# 32   | Emergency Food | Helping Hand Rescue Mission (Philly Restart)      | 19th & Ben Franklin Parkway, Philadelphia, PA, 19103 | 19103    | Mon                                                          | 4:00 PM    | 5:00 PM     | Women, Men, Families       | Restart has been serving meals every Monday (4pm) on the ... | 215-627-1656   | -75.1700704,39.957253
# 33   | Emergency Food | Helping Hand Rescue Mission                       | 610 N. 6th Street, Philadelphia, PA 19123            | 19123    | Sun                                                          | 1:30 PM    | nan         | Women, Men, Families       | We serve a first class meal on Sunday afternoons at the  ... | nan            | -75.1479812,39.9625561
# 46   | Emergency Food | Mercy Hospice                                     | 334 S 13th St, Philadelphia, PA 19107                | 19107    | Lunch Mon-Fri: Women with children 11am; Single women 12 ... | nan        | nan         | Women, Women with Children | Lunch Mon-Fri: Women with children 11am; Single women 12 ... | 215-545-5153   | -75.1630715,39.9456382
# ... (10 rows omitted)

# %% [markdown]
# **Challenge:** Find the places serving food that serve children

# %% [markdown]
# ## Chaining multiple conditions
# Suppose we want to find just the food services in the Temple zipcode. You can "chain" the where conditions, applying each to the result of the previous.

# %%
services.where('Zip Code', are.equal_to(19122)).where('Category', are.containing("Food"))
# Out:
# Id   | Category       | Organization Name          | Address                                 | Zip Code | Days                                       | Time: Open | Time: Close | People Served        | Description                                                  | Phone Number | LatLon
# 8    | Emergency Food | Bright Hope Baptist Church | 1601 N 12th St, Philadelphia, PA 19122  | 19122    | Mon - Thurs (6PM-6:45PM) & Sat (11AM-12PM) | 6:00 PM    | 6:45 PM     | Women, Men, Families | Monday-Thursday meals closed July and August; clothing,  ... | 215-232-6004 | -75.1540249,39.978021
# 50   | Emergency Food | Mt. Olive Holy Temple      | 1469 N Broad St, Philadelphia, PA 19122 | 19122    | Tuesday                                    | 12:00 PM   | 2:00 PM     | Women, Men, Families | Lunch Tues: 12-2pm                                           | 215-765-3372 | -75.1580833,39.9756058

# %% [markdown]
# ## Filtering by locations
# The dataset include a column "LatLon," but we really need two separate columns: one with the latitude and one with the longitude. To split this column requires a few advanced tricks we haven't covered yet, so I'm going to just show you how I did it with some comments as explanation, but you should come back to this after we learn about how to define function.
#
# Note: This technique may prove useful in the future is you use other datasets from OpenDataPhilly

# %%
# Create a function that splits a string on the comma and returns either the first or second piece.
def string_split(string, col):
    return float(string.split(',')[col])

# Vectorize the function so that we can apply it to an numpy array and it will operate on every element of the array
v_string_split = np.vectorize(string_split)

# %%
# Split the stings, creating two new numpy array
lat_lon = services.column('LatLon')
lon = v_string_split(lat_lon, 0)
lat = v_string_split(lat_lon, 1)

# %%
# We chain three methods:
# First, drop the old LatLon column, then add each of the new columns
services = services.drop('LatLon').with_column('Lat', lat).with_column('Lon', lon)

# %% [markdown]
# ## Making a Map
# Following [this example](https://inferentialthinking.com/chapters/08/5/Bike_Sharing_in_the_Bay_Area.html?highlight=map) in our textbook, let's use the new Lat Lon columns to make a map showing the locations of these services.
#
# You can zoom in, zoom out, pan, or click on a marker to see the label.

# %%
# Marker.map_table(stations.select('lat', 'long', 'name').relabel('name', 'labels'))
Marker.map_table(services.select('Lat', 'Lon', 'Organization Name').relabel('Organization Name', 'labels'))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81ed2bdf2b7ee495539fae5dd07ab166 {
#                     position: relative;
#                     width: 960.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81ed2bdf2b7ee495539fae5dd07ab166&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81ed2bdf2b7ee495539fae5dd07ab166 = L.map(
#                 &quot;map_81ed2bdf2b7ee495539fae5dd07ab166&quot;,
#                 {
#                     center: [39.989423450000004, -75.19693484999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     clusteredMarker: false,
#                     includeColorScaleOutliers: true,
#                     radiusInMeters: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e0dd7f3b1cda705de51955c009a1ce1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 17, &quot;maxZoom&quot;: 17, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81ed2bdf2b7ee495539fae5dd07ab166);
#
#
#             var marker_9468069da78cc45fd29e9b568b71cc79 = L.marker(
#                 [39.9635841, -75.18833430000001],
#                 {}
#             ).addTo(map_81ed2bdf2b7ee495539fae5dd07ab166);
#
#
#             var icon_15e47b6857ea58b4b126029e975b8f76 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sign-blank&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9468069da78cc45fd29e9b568b71cc79.setIcon(icon_15e47b6857ea58b4b126029e975b8f76);
#
#
#         var popup_af728225d51380d98d8b43fffb331164 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd9d47cb0efcb1a3bef96d774c314a04 = $(`&lt;div id=&quot;html_dd9d47cb0efcb1a3bef96d774c314a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A New Life Recovery &amp; Education Center&lt;/div&gt;`)[0];
#                 popup_af728225d51380d98d8b43fffb331164.setContent(html_dd9d47cb0efcb1a3bef96d774c314a04);
#
#
#
#         marker_9468069da78cc45fd29e9b568b71cc79.bindPopup(popup_af728225d51380d98d8b43fffb331164)
#         ;
#
#
#
#
#             var marker_9aa2388d276b13fdaf4d5cdf59fbe968 = L.marker(
#                 [39.97794469999999, -75.1812997],
#                 {}
#             ).addTo(map_81ed2bdf2b7ee495539fae5dd07ab166);
#
#
#             var icon_c4c0626fcade0db222b1e32d173ac20d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sign-blank&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9aa2388d276b13fdaf4d5cdf59fbe968.setIcon(icon_c4c0626fcade0db222b1e32d173ac20d);
#
#
#         var popup_dbcac16b93803570648d861e190090e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5708412f77410e7cfce3b5ba3774c46 = $(`&lt;div id=&quot;html_d5708412f77410e7cfce3b5ba3774c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ACTS Christian Transistional Services&lt;/div&gt;`)[0];
#                 popup_dbcac16b93803570648d861e190090e0.setContent(html_d5708412f77410e7cfce3b5ba3774c46);
#
#
#
#         marker_9aa2388d276b13fdaf4d5cdf59fbe968.bindPopup(popup_dbcac16b93803570648d861e190090e0)
#         ;
#
#
#
#
#             var marker_d0c85b8d1ebfc1d8be49c6de5244e8a1 = L.marker(
#                 [39.9554759, -75.1641606],
#                 {}
#             ).addTo(map_81ed2bdf2b7ee495539fae5dd07ab166);
#
#
#             var icon_22a4f0bbd549a1ec4f6cd24d07e763f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sign-blank&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0c85b8d1ebfc1d8be49c6de5244e8a1.setIcon(icon_22a4f0bbd549a1ec4f6cd24d07e763f7);
#
#
#         var popup_7b46f3c2704d740af682f62e595a4476 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2fee0cd136895b77bf2479607ff45107 = $(`&lt;div id=&quot;html_2fee0cd136895b77bf2479607ff45107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Apple Tree Family Center&lt;/div&gt;`)[0];
#                 popup_7b46f3c2704d740af682f62e595a4476.setContent(html_2fee0cd136895b77bf2479607ff45107);
#
#
#
#         marker_d0c85b8d1ebfc1d8be49c6de5244e8a1.bindPopup(popup_7b46f3c2704d740af682f62e595a4476)
#         ;
#
#
#
#
#             var marker_0c9d3666fe3dd761754ae6d60ee1209e = L.marker(
#                 [39.954096, -75.16290719999999],

# %% [markdown]
# ## All services North of Temple
#
# The coordinates of the Temple Bell Tower are: 39.9813° N, 75.1544° W
# Let's use the where filter to find only the services north of the bell tower.

# %%
bell_tower_lat = 39.9813

northern_services = services.where('Lat', are.above(bell_tower_lat))
Marker.map_table(northern_services.select('Lat', 'Lon', 'Organization Name').relabel('Organization Name', 'labels'))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f33d544cb4739a20207ceac096158ed2 {
#                     position: relative;
#                     width: 960.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f33d544cb4739a20207ceac096158ed2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f33d544cb4739a20207ceac096158ed2 = L.map(
#                 &quot;map_f33d544cb4739a20207ceac096158ed2&quot;,
#                 {
#                     center: [40.010217850000004, -75.1497138],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     clusteredMarker: false,
#                     includeColorScaleOutliers: true,
#                     radiusInMeters: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f9288bfae8c62e3fcab166acf47bfe0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 17, &quot;maxZoom&quot;: 17, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f33d544cb4739a20207ceac096158ed2);
#
#
#             var marker_48c46efeb0d7ea1754b0a4a138f173e0 = L.marker(
#                 [40.0090902, -75.1519844],
#                 {}
#             ).addTo(map_f33d544cb4739a20207ceac096158ed2);
#
#
#             var icon_a405f84cfeb1013f89b3ae294fbbe5e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sign-blank&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_48c46efeb0d7ea1754b0a4a138f173e0.setIcon(icon_a405f84cfeb1013f89b3ae294fbbe5e1);
#
#
#         var popup_a25d6bd84bea0df56c62177be3390b15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5a8394ea3188303cf30863b1f9cdbb7 = $(`&lt;div id=&quot;html_f5a8394ea3188303cf30863b1f9cdbb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Community Legal Services Inc&lt;/div&gt;`)[0];
#                 popup_a25d6bd84bea0df56c62177be3390b15.setContent(html_f5a8394ea3188303cf30863b1f9cdbb7);
#
#
#
#         marker_48c46efeb0d7ea1754b0a4a138f173e0.bindPopup(popup_a25d6bd84bea0df56c62177be3390b15)
#         ;
#
#
#
#
#             var marker_c65b4a3368ae77782fb22741a0f6ffdd = L.marker(
#                 [40.0356112, -75.17337309999999],
#                 {}
#             ).addTo(map_f33d544cb4739a20207ceac096158ed2);
#
#
#             var icon_5577241fedfe9856ebba489258f29d2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sign-blank&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c65b4a3368ae77782fb22741a0f6ffdd.setIcon(icon_5577241fedfe9856ebba489258f29d2f);
#
#
#         var popup_294eba3f4f0fa429e89634cd91532d6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16ac1b45eeaf1cb07b130342be4350e5 = $(`&lt;div id=&quot;html_16ac1b45eeaf1cb07b130342be4350e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Covenant House&lt;/div&gt;`)[0];
#                 popup_294eba3f4f0fa429e89634cd91532d6e.setContent(html_16ac1b45eeaf1cb07b130342be4350e5);
#
#
#
#         marker_c65b4a3368ae77782fb22741a0f6ffdd.bindPopup(popup_294eba3f4f0fa429e89634cd91532d6e)
#         ;
#
#
#
#
#             var marker_2751bd27f465e08a1ded1a0143942b66 = L.marker(
#                 [39.98468949999999, -75.1726314],
#                 {}
#             ).addTo(map_f33d544cb4739a20207ceac096158ed2);
#
#
#             var icon_ef862d9adce1359752f5a6f48f82004a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sign-blank&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2751bd27f465e08a1ded1a0143942b66.setIcon(icon_ef862d9adce1359752f5a6f48f82004a);
#
#
#         var popup_8ff6085322e1365493bd9033805ac2a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4066a4308ea44aef9ecf031ab51522b5 = $(`&lt;div id=&quot;html_4066a4308ea44aef9ecf031ab51522b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Honickman Learning Center and Comcast Technology Labs&lt;/div&gt;`)[0];
#                 popup_8ff6085322e1365493bd9033805ac2a6.setContent(html_4066a4308ea44aef9ecf031ab51522b5);
#
#
#
#         marker_2751bd27f465e08a1ded1a0143942b66.bindPopup(popup_8ff6085322e1365493bd9033805ac2a6)
#         ;
#
#
#
#
#             var marker_02be435a98e20e1679b5ea0b2edb2d0b = L.marker(
#                 [39.987926, -75.17976999999999],
#                 {}

# %% [markdown]
# **Challenge:** Plot just the sevices in the Temple zipcode.

# %% [markdown]
# # Summary
# I hope you had fun. The where() method is not that hard once you understand the basic idea. I encourage you to explore this data set and see if you can discover any interesting patterns!
